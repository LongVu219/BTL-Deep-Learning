# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

import numpy as np
from torch.utils.data import TensorDataset, DataLoader, RandomSampler

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import time
import math
import collections

from pathlib import Path
from pyvi import ViTokenizer


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_size = 164
hidden_size = 64

all_data_path = '.data/multi30k'
train_en_path = all_data_path + '/train.en'
train_vi_path = all_data_path + '/train.vi'
val_en_path = all_data_path + '/val.en'
val_vi_path = all_data_path + '/val.vi'
test_en_path = all_data_path + '/test2016.en'
test_vi_path = all_data_path + '/test2016.vi'

# %%
SOS_token = 0
EOS_token = 1

class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {"SOS": 0, "EOS": 1, "UNK": 2}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS", 2: "UNK"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
def readLangs(lang1_path, lang2_path):
    print("Reading lines...")

    # Read the file and split into lines
    lines1 = open(lang1_path, encoding='utf-8').\
        read().strip().split('\n')

    lines2 = open(lang2_path, encoding='utf-8').\
        read().strip().split('\n')

    lines1 = [s.lower() for s in lines1]
    lines2 = [ViTokenizer.tokenize(s.lower()) for s in lines2]

    pairs = paired_sentences = list(zip(lines1, lines2))

    # Reverse pairs, make Lang instances

    input_lang = Lang(lang1_path)
    output_lang = Lang(lang2_path)

    return input_lang, output_lang, pairs

# %%
def prepareData(lang1, lang2):
    input_lang, output_lang, pairs = readLangs(lang1, lang2)
    print("Read %s sentence pairs" % len(pairs))
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs

_1, _2, pairs = prepareData(val_en_path, val_vi_path)
# Out:
# Reading lines...
# Read 1530 sentence pairs
# Trimmed to 1530 sentence pairs
# Counting words...
# Counted words:
# .data/multi30k/val.en 3393
# .data/multi30k/val.vi 3017

# %%
MAX_LENGTH = 80

class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size, dropout_p=0.1):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, num_layers=1, batch_first=True)
        self.dropout = nn.Dropout(dropout_p)

    def forward(self, input):
        embedded = self.dropout(self.embedding(input))
        output, hidden = self.gru(embedded)
        return output, hidden

class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, num_layers=1, batch_first=True)
        self.out = nn.Linear(hidden_size, output_size)

    def forward(self, encoder_outputs, encoder_hidden, target_tensor=None):
        batch_size = encoder_outputs.size(0)
        decoder_input = torch.empty(batch_size, 1, dtype=torch.long, device=device).fill_(SOS_token)
        decoder_hidden = encoder_hidden
        decoder_outputs = []

        for i in range(MAX_LENGTH):
            decoder_output, decoder_hidden  = self.forward_step(decoder_input, decoder_hidden)
            decoder_outputs.append(decoder_output)

            if target_tensor is not None:
                decoder_input = target_tensor[:, i].unsqueeze(1) # Teacher forcing
            else:
                _, topi = decoder_output.topk(1)
                decoder_input = topi.squeeze(-1).detach()  # detach from history as input

        decoder_outputs = torch.cat(decoder_outputs, dim=1)
        decoder_outputs = F.log_softmax(decoder_outputs, dim=-1)
        return decoder_outputs, decoder_hidden, None # We return `None` for consistency in the training loop

    def forward_step(self, input, hidden):
        output = self.embedding(input)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.out(output)
        return output, hidden

class BahdanauAttention(nn.Module):
    def __init__(self, hidden_size):
        super(BahdanauAttention, self).__init__()
        self.Wa = nn.Linear(hidden_size, hidden_size)
        self.Ua = nn.Linear(hidden_size, hidden_size)
        self.Va = nn.Linear(hidden_size, 1)

    def forward(self, query, keys):
        scores = self.Va(torch.tanh(self.Wa(query) + self.Ua(keys)))
        scores = scores.squeeze(2).unsqueeze(1)

        weights = F.softmax(scores, dim=-1)
        context = torch.bmm(weights, keys)

        return context, weights

class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1):
        super(AttnDecoderRNN, self).__init__()
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.attention = BahdanauAttention(hidden_size)
        self.gru = nn.GRU(2 * hidden_size, hidden_size, batch_first=True)
        self.out = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout_p)

    def forward(self, encoder_outputs, encoder_hidden, target_tensor=None):
        batch_size = encoder_outputs.size(0)
        decoder_input = torch.empty(batch_size, 1, dtype=torch.long, device=device).fill_(SOS_token)
        decoder_hidden = encoder_hidden
        decoder_outputs = []
        attentions = []

        for i in range(MAX_LENGTH):
            decoder_output, decoder_hidden, attn_weights = self.forward_step(
                decoder_input, decoder_hidden, encoder_outputs
            )
            decoder_outputs.append(decoder_output)
            attentions.append(attn_weights)

            if target_tensor is not None:
                decoder_input = target_tensor[:, i].unsqueeze(1)
            else:
                _, topi = decoder_output.topk(1)
                decoder_input = topi.squeeze(-1).detach()

        decoder_outputs = torch.cat(decoder_outputs, dim=1)
        decoder_outputs = F.log_softmax(decoder_outputs, dim=-1)
        attentions = torch.cat(attentions, dim=1)

        return decoder_outputs, decoder_hidden, attentions


    def forward_step(self, input, hidden, encoder_outputs):
        embedded =  self.dropout(self.embedding(input))

        query = hidden.permute(1, 0, 2)
        context, attn_weights = self.attention(query, encoder_outputs)
        input_gru = torch.cat((embedded, context), dim=2)

        output, hidden = self.gru(input_gru, hidden)
        output = self.out(output)

        return output, hidden, attn_weights

def indexesFromSentence(lang, sentence):
    res = []
    for word in (sentence.split(' ')):
        if (word not in lang.word2index): 
            word = "UNK"
        res.append(lang.word2index[word])
    return res

def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(1, -1)

def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

def get_dataloader(path1, path2):
    input_lang, output_lang, pairs = prepareData(path1, path2)

    n = len(pairs)
    input_ids = np.zeros((n, MAX_LENGTH), dtype=np.int32)
    target_ids = np.zeros((n, MAX_LENGTH), dtype=np.int32)

    for idx, (inp, tgt) in enumerate(pairs):
        inp_ids = indexesFromSentence(input_lang, inp)
        tgt_ids = indexesFromSentence(output_lang, tgt)
        inp_ids.append(EOS_token)
        tgt_ids.append(EOS_token)
        input_ids[idx, :len(inp_ids)] = inp_ids
        target_ids[idx, :len(tgt_ids)] = tgt_ids

    train_data = TensorDataset(torch.LongTensor(input_ids).to(device),
                               torch.LongTensor(target_ids).to(device))

    train_sampler = RandomSampler(train_data)
    train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)
    return input_lang, output_lang, train_dataloader

input_lang, output_lang, train_dataloader = get_dataloader(train_en_path, train_vi_path)
_1, _2, val_dataloader = get_dataloader(val_en_path, val_vi_path)
_1, _2, test_dataloader = get_dataloader(test_en_path, test_vi_path)
# Out:
# Reading lines...
# Read 128134 sentence pairs
# Trimmed to 128134 sentence pairs
# Counting words...
# Counted words:
# .data/multi30k/train.en 44877
# .data/multi30k/train.vi 31979
# Reading lines...
# Read 1530 sentence pairs
# Trimmed to 1530 sentence pairs
# Counting words...
# Counted words:
# .data/multi30k/val.en 3393
# .data/multi30k/val.vi 3017
# Reading lines...
# Read 1207 sentence pairs
# Trimmed to 1207 sentence pairs
# Counting words...
# Counted words:
# .data/multi30k/test2016.en 3360
# .data/multi30k/test2016.vi 3047

# %%
def train_epoch(dataloader, encoder, decoder, encoder_optimizer,
          decoder_optimizer, criterion):

    total_loss = 0
    for i, data in enumerate(dataloader):
        input_tensor, target_tensor = data

        encoder_optimizer.zero_grad()
        decoder_optimizer.zero_grad()

        encoder_outputs, encoder_hidden = encoder(input_tensor)
        decoder_outputs, _, _ = decoder(encoder_outputs, encoder_hidden, target_tensor)

        loss = criterion(
            decoder_outputs.view(-1, decoder_outputs.size(-1)),
            target_tensor.view(-1)
        )
        loss.backward()

        encoder_optimizer.step()
        decoder_optimizer.step()

        total_loss += loss.item()
        torch.cuda.empty_cache()

        if (i%100 == 0):
            print('step :', round((i / len(dataloader)) * 100, 2), '% , loss :', loss.item())

    return total_loss / len(dataloader)

def get_bleu(pred_seq, label_seq, k = 4):
    pred_tokens, label_tokens = pred_seq.split(' '), label_seq.split(' ')
    len_pred, len_label = len(pred_tokens), len(label_tokens)
    score = math.exp(min(0, 1 - len_label / len_pred))


    for n in range(1, min(k, len_pred) + 1):
        num_matches, label_subs = 0, collections.defaultdict(int)
        for i in range(len_label - n + 1):
            label_subs[' '.join(label_tokens[i: i + n])] += 1

        for i in range(len_pred - n + 1):
            if label_subs[' '.join(pred_tokens[i: i + n])] > 0:
                num_matches += 1
                label_subs[' '.join(pred_tokens[i: i + n])] -= 1
        
        score *= math.pow(num_matches / (len_pred - n + 1), math.pow(0.5, n))
    return score



def evaluate(encoder, decoder, sentence, input_lang, output_lang):
    
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)

        encoder_outputs, encoder_hidden = encoder(input_tensor)
        decoder_outputs, decoder_hidden, decoder_attn = decoder(encoder_outputs, encoder_hidden)
        _, topi = decoder_outputs.topk(1)
        decoded_ids = topi.squeeze()

        decoded_words = []
        for idx in decoded_ids:
            if idx.item() == EOS_token:
                break
            decoded_words.append(output_lang.index2word[idx.item()])
    return decoded_words, decoder_attn

def change_tensor2word(tensor, lang):

    sentence = []
    for num in tensor:
        if num.item() == EOS_token:
            sentence.append('EOS')
            break
        sentence.append(lang.index2word[num.item()])
    
    return ' '.join(sentence)

def valid_epoch(dataloader, encoder, decoder, encoder_optimizer,
          decoder_optimizer, criterion, input_lang, output_lang):
    
    total_loss, total_bleu = 0, []

    with torch.no_grad():
        for i, data in enumerate(dataloader):
            input_tensor, target_tensor = data


            encoder_outputs, encoder_hidden = encoder(input_tensor)
            decoder_outputs, _, _ = decoder(encoder_outputs, encoder_hidden, target_tensor)

            loss = criterion(
                decoder_outputs.view(-1, decoder_outputs.size(-1)),
                target_tensor.view(-1)
            )
            
            #print(data)

            for j in range(0, len(input_tensor)):
                
                p0 = input_tensor[j]
                p1 = target_tensor[j]

                src_sen = change_tensor2word(p0, input_lang)
                trg_sen = change_tensor2word(p1, output_lang)

                #print(src_sen + "lmaolmao")
                #print(trg_sen + "bruhbruh")

                output_words, _ = evaluate(encoder, decoder, src_sen, input_lang, output_lang)
                output_sentence = ' '.join(output_words)
                
                #print(output_words)

                bleu = get_bleu(output_sentence, trg_sen)
                total_bleu.append(bleu)

            total_loss += loss.item()
            torch.cuda.empty_cache()

    batch_bleu = sum(total_bleu) / len(total_bleu)
    return total_loss / len(dataloader), batch_bleu

# %%
def save_model(name):
    MODEL_PATH = Path('models')
    MODEL_ENC_NAME = Path(name + '_encoder.pth')
    MODEL_DEC_NAME = Path(name + '_decoder.pth')
    ENC_SAVE_PATH = MODEL_PATH / MODEL_ENC_NAME
    DEC_SAVE_PATH = MODEL_PATH / MODEL_DEC_NAME
    #print(f'Saving model to : {MODEL_SAVE_PATH}')
    torch.save(obj = encoder.state_dict(),
            f = ENC_SAVE_PATH)
    torch.save(obj = decoder.state_dict(),
            f = DEC_SAVE_PATH)

inf = float('inf')
def train(train_dataloader, encoder, decoder, n_epochs, learning_rate=0.0005,
               best_loss = inf, best_bleu = 0, input_lang=input_lang, output_lang=output_lang):
    start = time.time()

    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate)
    criterion = nn.CrossEntropyLoss(ignore_index=0)

    for epoch in range(0, n_epochs):
        start_time = time.time()
        train_loss = train_epoch(train_dataloader, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)
        valid_loss, bleu = valid_epoch(val_dataloader, encoder, decoder, 
                                       encoder_optimizer, decoder_optimizer, criterion,
                                       input_lang, output_lang)
        end_time = time.time()

        if valid_loss < best_loss:
            best_loss = valid_loss
            save_model('gru_best_loss')
        
        if (bleu > best_bleu):
            best_bleu = bleu
            save_model('gru_best_bleu')
        
        print(f'Epoch: {epoch + 1}')
        print(f'Epoch time : {(end_time - start_time)/3600}hrs')
        print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
        print(f'\tVal Loss: {valid_loss:.3f} |  Val PPL: {math.exp(valid_loss):7.3f}')
        print(f'\tBLEU Score: {bleu:.3f}')
    
    end = time.time()
    print(f'Training time : {(end - start)/3600}hrs')

    test_loss, test_bleu = valid_epoch(test_dataloader, encoder, decoder, 
                                   encoder_optimizer, decoder_optimizer, criterion,
                                   input_lang, output_lang)
    
    print('Test Result : ------------------------')
    print(f'Loss : {test_loss}')
    print(f'BLEU : {test_bleu}')

# %%
def evaluateRandomly(encoder, decoder, n=1000):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, _ = evaluate(encoder, decoder, pair[0], input_lang, output_lang)
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

encoder = EncoderRNN(input_lang.n_words, hidden_size).to(device)
decoder = AttnDecoderRNN(hidden_size, output_lang.n_words).to(device)

print(f'The model has {count_parameters(encoder) + count_parameters(decoder)} params')

train(train_dataloader, encoder, decoder, 5)
# Out:
# The model has 7068012 params
# step : 0.0 % , loss : 10.396987915039062
# step : 12.79 % , loss : 6.207138538360596
# step : 25.58 % , loss : 6.243095397949219
# step : 38.36 % , loss : 6.065656661987305
# step : 51.15 % , loss : 6.063226699829102
# step : 63.94 % , loss : 5.989120006561279
# step : 76.73 % , loss : 5.853017330169678
# step : 89.51 % , loss : 5.846051216125488
# Epoch: 1
# Epoch time : 0.11570071637630462hrs
# 	Train Loss: 6.209 | Train PPL: 497.138
# 	Val Loss: 9.115 |  Val PPL: 9091.008
# 	BLEU Score: 0.000
# step : 0.0 % , loss : 5.731564998626709
# step : 12.79 % , loss : 5.6155805587768555
# step : 25.58 % , loss : 5.525924205780029
# step : 38.36 % , loss : 5.424081325531006
# step : 51.15 % , loss : 5.362383842468262
# step : 63.94 % , loss : 5.343886375427246
# step : 76.73 % , loss : 5.193467617034912
# step : 89.51 % , loss : 5.141269207000732
# Epoch: 2
# Epoch time : 0.11133567326598698hrs
# 	Train Loss: 5.412 | Train PPL: 223.975
# 	Val Loss: 9.098 |  Val PPL: 8934.620
# 	BLEU Score: 0.000
# step : 0.0 % , loss : 5.232295989990234
# step : 12.79 % , loss : 5.018324375152588
# step : 25.58 % , loss : 5.052680969238281
# step : 38.36 % , loss : 4.999314308166504
# step : 51.15 % , loss : 4.954347610473633
# step : 63.94 % , loss : 4.872082233428955
# step : 76.73 % , loss : 4.8196516036987305
# step : 89.51 % , loss : 4.826229572296143
# Epoch: 3
# Epoch time : 0.11137529247336918hrs
# 	Train Loss: 4.969 | Train PPL: 143.816
# 	Val Loss: 9.129 |  Val PPL: 9221.577
# 	BLEU Score: 0.000
# step : 0.0 % , loss : 4.89271879196167
# step : 12.79 % , loss : 4.652454853057861
# step : 25.58 % , loss : 4.639781475067139
# step : 38.36 % , loss : 4.622982025146484
# step : 51.15 % , loss : 4.5920634269714355
# step : 63.94 % , loss : 4.5828752517700195
# step : 76.73 % , loss : 4.611417770385742
# step : 89.51 % , loss : 4.560924530029297
# Epoch: 4
# Epoch time : 0.1114896861049864hrs
# 	Train Loss: 4.695 | Train PPL: 109.354
# 	Val Loss: 9.230 |  Val PPL: 10200.735
# 	BLEU Score: 0.000
# step : 0.0 % , loss : 4.491749286651611
# step : 12.79 % , loss : 4.623950958251953
# step : 25.58 % , loss : 4.563135147094727
# step : 38.36 % , loss : 4.521730422973633
# step : 51.15 % , loss : 4.468428611755371
# step : 63.94 % , loss : 4.428369998931885
# step : 76.73 % , loss : 4.469822883605957
# step : 89.51 % , loss : 4.411309242248535
# Epoch: 5
# Epoch time : 0.11149354689651066hrs
# 	Train Loss: 4.499 | Train PPL:  89.928
# 	Val Loss: 9.296 |  Val PPL: 10897.521
# 	BLEU Score: 0.000
# Training time : 0.56169922583633hrs
# Test Result : ------------------------
# Loss : 9.125263333320618
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 9>()
#       5 decoder = AttnDecoderRNN(hidden_size, output_lang.n_words).to(device)
#       7 print(f'The model has {count_parameters(encoder) + count_parameters(decoder)} params')
# ----> 9 train(train_dataloader, encoder, decoder, 5)
#
# Input In [7], in train(train_dataloader, encoder, decoder, n_epochs, learning_rate, best_loss, best_bleu, input_lang, output_lang)
#      51 print('Test Result : ------------------------')
#      52 print(f'Loss : {test_loss}')
# ---> 53 print(f'BLEU : {test_bleu}')
#
# NameError: name 'test_bleu' is not defined

# %%
encoder.eval()
decoder.eval()
evaluateRandomly(encoder, decoder)
# Out:
# > for a year we were penniless .
# = trong suốt một năm chúng_tôi không một xu dính túi .
# < và nó là một người đã làm .
#
# > your skin cell is really useless without a heart cell , muscle cell , a brain cell and so on .
# = tế_bào da của mọi người sẽ không có tác_dụng gì nếu thiếu sự tồn_tại của thế bào tim , tế_bào cơ , tế_bào não và rất nhiều tế_bào khác .
# < và nó là một người đã làm .
#
# > words , for so long his friends , now mocked him .
# = ngôn_từ , qua bao năm_tháng là bạn đồng_hành với ông , giờ quay ra chế_giễu ông .
# < và tôi đã làm .
#
# > and he described one of them as very ' common . '
# = ông miêu_tả một trong số chúng là rất ' thông_thường '
# < và tôi đã làm .
#
# > and as soon as i walked inside , the judge saw me coming in .
# = và khi tôi bước vào , thẩm_phán nhìn thấy tôi đến
# < và tôi đã làm .
#
# > i gave her aspirin . i gave her medications to relieve the strain on her heart .
# = tôi cho bà uống aspirin . tôi kê thuốc để giảm hoạt_động của tim .
# < tôi đã làm .
#
# > i think we have to do something about a piece of the culture of medicine that has to change .
# = tôi nghĩ ta phải làm gì đó về một ' truyền_thống ' trong y_học cần phải thay_đổi .
# < tôi đã làm là một người khác , tôi đã làm .
#
# > because that 's what you do when your name is yosemite mountain bear .
# = bởi_vì đó là những gì bạn làm khi bạn là yosemite mountain bear ( con gấu ở núi yosemite .
# < và tôi đã làm là một người khác .
#
# > when i was about 14 or 15 , one day my brother came home and he had this six-pack of beer -- i don 't know where he got it -- and he grabbed me and my sister and we went out in the woods .
# = đến khi tôi 14 , 15 tuổi một ngày_kia , anh tôi về nhà và mang về 6 chai bia tôi không biết anh ấy có nó từ đâu anh ấy kéo tôi và đứa em_gái cùng đi vào rừng
# < tôi đã làm là một người khác , tôi đã làm .
#
# > in the possibilities of linking together magic , the earth and technology , there are multiple possibilities .
# = trong khả_năng kết_nối lại phép màu , trái_đất và công_nghệ , còn rất nhiều khả_năng khác nữa .
# < và nó là một người đã làm .
#
# > so these communities began to evolve so that the interesting level on which evolution was taking place was no longer a cell , but a community which we call an organism .
# = do đó , những quần_thể này bắt_đầu tiến_hoá khiến mức_độ thú_vị mà tiến_hoá xảy ra không còn là trên một tế_bào , mà trên một quần_thể chúng_ta gọi là cơ_thể sống .
# < và tôi đã làm là một người khác .
#
# > and my patients aren 't cars ; they don 't tell me their symptoms in the same way each time .
# = và bệnh_nhân của tôi không phải ô - tô ; không phải mỗi lần họ đều thuật lại triệu_chứng theo cách giống nhau .
# < và tôi đã làm là một người khác .
#
# > if you are a suspect in a criminal case , well it 's pretty obvious , your phone will be tapped .
# = nếu bạn đang bị nghi_ngờ có dính_líu đến một tội_ác nào đó , thì điều chắc_chắn là điện_thoại của bạn đang có ' rệp ' .
# < và tôi đã làm là một người khác .
#
# > now in the financial savings world , i think one of the best examples that has recently come out on how to best manage the choice offerings has actually been something that david laibson was heavily involved in designing , which was the program that they have at harvard .
# = bây_giờ trong thế_giới tiết_kiệm tài_chính , tôi nghĩ rằng 1 trong những ví_dụ tốt nhất để làm_sao đưa ra những sự lựa_chọn tốt nhất đó là việc david laibson liên_quan đến việc thiết_kế đó là chương_trình ở harvard
# < tôi đã làm là một người khác , tôi đã làm .
#
# > and i was up too late one night and i starting thinking , well gosh , if the judge can turn you into something that you 're not , the judge must have magic power .
# = và có một đêm , tôi thức rất khuya và bắt_đầu nghĩ lạ nhỉ , nếu quan toà có_thể làm vậy thì hẳn là họ có quyền_lực vô_biên
# < tôi đã làm là một người khác , tôi đã làm là một người khác , tôi đã làm .
#
# > i personally think that it 's easier to actually create a place than to find a place , because then you don 't need to compromise with the ideas in your head .
# = cá_nhân tôi nghĩ rằng sẽ dễ hơn để thậm_chí tạo ra bối_cảnh hơn là tìm ra bối_cảnh , vì tiếp đó bạn không cân phải sắp_xếp các ý_tưởng trong đầu nữa .
# < tôi đã làm là một người khác , tôi đã làm .
#
# > your skin cell is really useless without a heart cell , muscle cell , a brain cell and so on .
# = tế_bào da của mọi người sẽ không có tác_dụng gì nếu thiếu sự tồn_tại của thế bào tim , tế_bào cơ , tế_bào não và rất nhiều tế_bào khác .
# < và nó là một người đã làm .
#
# > and so the next stage that 's interesting in life took about another billion years .
# = và vì_vậy , quá_trình tiếp_theo rất thú_vị trong sự sống mất khoảng 1 tỉ năm nữa .
# < và tôi đã làm .
#
# > i ordered some fluids to rehydrate him and asked my colleague to reassess him .
# = tôi yêu_cầu tiếp nước để bệnh_nhân đỡ mất nước và nhờ đồng_nghiệp khám lại cho anh ta .
# < tôi đã làm .
#
# > but what are we doing with it ?
# = nhưng ta đang làm gì với nó vậy ?
# < và tôi đã làm .
#
# > people seem to think politics is sexy .
# = có người cho rằng chính_trị rất hấp_dẫn .
# < và nó là một người đã làm .
#
# > well there are opportunities all around us .
# = à , luôn có nhiều cơ_hội xung_quanh chúng_ta .
# < và tôi đã làm .
#
# > and he had posted lots of nature videos in fact .
# = thực_ra ông ấy đã đăng rất nhiều video về thiên_nhiên .
# < và tôi đã làm .
#
# > and i had a client who was 14 years old , a young , poor black kid .
# = rằng tôi có một thân_chủ mới 14 tuổi , là người da đen và nghèo_khó
# < tôi đã làm .
#
# > and if you 're wondering about those other spikes , those are also fridays .
# = và nếu_như bạn đang tự hỏi về những đỉnh_điểm khác , chúng cũng vào những ngày thứ 6 .
# < và tôi đã làm là một người khác .
#
# > and it felt like technology should enable magic , not kill it .
# = và có vẻ như công_nghệ mới đáng_lẽ_phải tạo ra phép màu , chứ không phải tiêu_diệt nó .
# < và tôi đã làm .
#
# > and the first story is about charles darwin , one of my heroes .
# = câu_chuyện thứ nhất là về charles darwin , một trong những vị anh_hùng của tôi
# < và tôi đã làm .
#
# > and this piece of 50-year-old technology became the most magical thing to me .
# = và cái mảnh công_nghệ 50 năm_tuổi này trở_thành vật_thể màu_nhiệm nhất đối_với tôi .
# < và tôi đã làm .
#
# > now there 's a very large community of people that are building the tools that we need to do things together effectively .
# = ngày_nay có một cộng_đồng lớn những người giúp xây_dựng các công_cụ cần_thiết để chúng_ta cùng nhau làm_việc hiệu_quả .
# < và tôi đã làm là một người khác .
#
# > what you find is the people who go from high choice to low choice , they 're hitting that default button over and over and over again .
# = điều bạn tìm_kiếm đó là mọi người đi từ sự lựa_chọn nhiều xuống thấp hơn nọ đang nhấn nút ' mặc_định ' tiếp và tiếp_tục lần nữa .
# < và tôi đã làm là một người khác .
#
# > have you seen these guys ?
# = bạn đã bao_giờ thấy những con_người này ?
# < và tôi đã làm .
#
# > for example , in germany , just a couple of weeks ago the so-called state trojan was found , which was a trojan used by german government officials to investigate their own citizens .
# = ví_dụ như ở đức , vài tuần trước đây người_ta đã phát_hiện ra trojan scuinst , là một loại trojan được nhân_viên chính_phủ đức sử_dụng để điều_tra người dân của họ .
# < và nó là một người đã làm .
#
# > let 's say i want to sort numbers , as a simple example i 've done it with .
# = khi tôi muốn sắp_xếp các số , một ví_dụ đơn_giản mà tôi thực_hiện được .
# < tôi đã làm là một người khác , tôi đã làm .
#
# > well i was nine years old , so i said , ' yes , mama . i 'll do that . '
# = à , lúc đó tôi mới 9 tuổi nên tôi nói ' vâng , con hứa ạ '
# < tôi đã làm là một người khác , tôi đã làm .
#
# > they were there in february , and it snowed a lot in february last year .
# = họ ở đó trong tháng hai đầy tuyết .
# < và tôi đã làm .
#
# > and part of the narrative of that is sometimes that it 's about increased incarceration rates .
# = và một phần của câu_chuyện đó là đôi_khi là do tăng thời_gian giam_giữ .
# < và tôi đã làm .
#
# > now these decisions vary in the number of choices that they offer per decision .
# = và những lựa_chọn đó làm thay_đổi 1 lượng sự lựa_chọn mà họ đưa ra mỗi quyết_định .
# < và tôi đã làm .
#
# > she 's supportive when other people talk about their mistakes .
# = chị rất ủng_hộ khi người khác nói về sai_lầm của họ .
# < và tôi đã làm .
#
# > they 're obscure , weird programs .
# = chúng là những chương_trình rất mơ_hồ và kì_quặc .
# < và nó là một người đã làm .
#
# > because the transition seems very , very confusing when we 're right in the middle of it .
# = bởi_vì quá_trình chuyển_giao này có vẻ rất khó đoán biết khi chúng_ta đang ở ngay giữa của quá_trình ấy .
# < và tôi đã làm là một người khác .
#
# > and they did .
# = và tiếng đó dừng thật .
# < và nó là một người khác .
#
# > so when they 're faced with the problem of government , they don 't care as much about using their voices .
# = khi họ đối_mặt với vấn_đề của chúng_phủ , họ có_thể không quan_tâm lắm đến việc sử_dụng tiếng_nói của mình .
# < và tôi đã làm .
#
# > most of our ideas were crazy , but a few were brilliant , and we broke through .
# = hầu_hết_ý_tưởng của chúng_tôi đều điên_khùng , nhưng vài ý_tưởng vô_cùng tuyệt_vời , và chúng_tôi tạo ra đột_phá .
# < và tôi đã làm .
#
# > well i believe that our identity is at risk .
# = tôi cho rằng nhân_cách của chúng_ta đang bị mai_một
# < tôi đã làm .
#
# > so i 've got now a new generation of programs that are produced by combinations of the programs that did a little bit better job .
# = tôi có hiện_nay một thế_hệ chương_trình mới được sản_xuất bởi sự kết_hợp của các chương_trình mà thực_hiện công_việc tốt hơn một_chút .
# < tôi đã làm .
#
# > the second story , also to illustrate another concept , is called shifting waistline .
# = câu_chuyện thứ hai , vẫn là để chú giải cho một khái_niệm khác cái được gọi là sự dịch_chuyển của đường hông .
# < và nó là một người đã làm .
#
# > and it could have connected them with government services if they 'd been needed , but a neighbor is a far better and cheaper alternative to government services .
# = nếu cần_thiết , các dịch_vụ của chính_phủ có_thể giúp_đỡ họ kết_nối lại , nhưng một người hàng_xóm thì là một giải_pháp tốt và tiết_kiệm hơn so với các dịch_vụ của chính_phủ .
# < và tôi đã làm .
#
# > i 've learned very simple things doing the work that i do .
# = tôi đã học được những điều rất đơn_giản khi làm công_việc của mình .
# < tôi đã làm .
#
# > if you 're a doctor you can do some good things , but if you 're a caring doctor you can do some other things .
# = còn nếu bạn là một bác_sĩ , bạn có_thể làm vài điều tốt nhưng nếu bạn là một bác_sĩ tận_tâm , bạn có_thể làm thêm nhiều điều tốt khác .
# < và tôi đã làm là một người khác , tôi đã làm là một người khác .
#
# > so the first steps of the story that i told you about took a billion years a piece .
# = vì_vậy những bước đầu_tiên của câu_chuyện tôi kể cho mọi người xảy ra trong 1 tỉ năm .
# < tôi đã làm .
#
# > and it worked for a while , until i met mrs. drucker .
# = và giả_thuyết ấy có vẻ đúng được một lúc cho tới khi tôi gặp bà drucker .
# < và tôi đã làm .
#
# > speaking of the environmental crisis , i think a big problem has been in the last 10 years is that children have been locked inside their rooms , glued to their pcs , they haven 't been able to get out .
# = tiện_thể nói về vấn_nạn môi_trường , tôi nghĩ một vấn_đề lớn trong 10 năm gần đây là các em nhỏ đã bị nhốt trong phòng , dán mắt vào màn_hình máy_tính , các em không ra ngoài chơi được .
# < tôi đã làm là một người khác , tôi đã làm .
#
# > the idea behind littlebits is that it 's a growing library .
# = ý_tưởng đằng sau littlebits là xem nó như_thể một dạng thư_viện đang được phát_triển .
# < và nó là một người đã làm .
#
# > either it 's going to turn into a sort of classical s-curve like this , until something totally different comes along , or maybe it 's going to do this .
# = hoặc nó sẽ biến thành một dạng đường_cong s như thế này , cho tới khi một việc gì đó khác_biệt hoàn_toàn xảy ra , hoặc có_thể , nó sẽ chuyển thành thế này .
# < và tôi đã làm là một người khác .
#
# > and the next morning , i woke up and i thought , now did i dream that crazy motion , or did i actually write it ?
# = sáng hôm sau , tôi thức dậy và nghĩ , tôi đã mơ về một bản kiến_nghị điên_rồ hay tôi thực_sự đã viết nó ?
# < và tôi đã làm , tôi đã làm .
#
# > he just wanted to share a rainbow .
# = ông ấy chỉ muốn mọi người nhìn thấy cầu_vồng .
# < tôi đã làm .
#
# > i represent people on death row .
# = tôi xin lên_tiếng làm đại_diện cho những người tử_tù
# < tôi đã làm .
#
# > he said , ' mr. stevenson , did you write this crazy motion ? '
# = ông nói : ' anh stevenson , có phải chính anh đã viết đơn kiến_nghị điên_rồ này không ? '
# < và tôi đã làm là một người khác .
#
# > i 'm sitting here making grunting sounds basically , and hopefully constructing a similar messy , confused idea in your head that bears some analogy to it .
# = tôi đang ngồi đây nói ra những tiếng lẩm_bẩm , hy_vọng tạo ra trong đầu mọi người một suy_nghĩ cũng hỗn_độn và mơ_hồ và có đôi_chút tương_tự như suy_nghĩ của tôi .
# < tôi đã làm .
#
# > twice in one emergency shift , i missed appendicitis .
# = hai lần trong một ca trực cấp_cứu , tôi không chẩn đúng bệnh viêm ruột_thừa .
# < tôi đã làm .
#
# > there is no disconnect around technology and design that will allow us to be fully human until we pay attention to suffering , to poverty , to exclusion , to unfairness , to injustice .
# = có sự ngăn_cách giữa công_nghệ và thiết_kế cho phép chúng_ta là con_người thực_thụ chỉ khi nào chúng_ta thực_sự chú_ý đến_nỗi thống_khổ sự nghèo_khó , không cho ai đó được hưởng được quyền_lợi và sự bất_công
# < và tôi đã làm là một người khác .
#
# > and that was the message that i absorbed when i was in med school .
# = và đó là thông_điệp tôi thấm_nhuần khi tôi học trường y .
# < và tôi đã làm .
#
# > it 's interesting to me .
# = nhưng điều này lại khiến tôi quan_tâm
# < và tôi đã làm là một người khác .
#
# > now the question that i 'd like to ask is , if you look at these exponential curves , they don 't go on forever .
# = giờ câu hỏi tôi muốn đặt ra là , nếu bạn nhìn vào những đường_cong theo quy_luật số_mũ này , chúng không nhân lên mãi_mãi .
# < tôi đã làm là một người khác , tôi đã làm .
#
# > and i went through this roller coaster , because after they stabilized her , she went to the intensive care unit , and i hoped against hope that she would recover .
# = và tôi như ngồi trên tàu lượn siêu_tốc , vì sau khi bà vào trạng_thái ổn_định , bà được đưa vào bộ_phận chăm_sóc đặc_biệt , và tôi hi_vọng viển_vông là bà sẽ bình_phục .
# < tôi đã làm là một người khác , tôi đã làm .
#
# > so i would like to say that there are three simple rules to follow to achieve a realistic result .
# = nên tôi muốn đưa ra ba nguyên_tắc cơ_bản cần tuân theo để đạt được một kết_quả như_ý .
# < tôi đã làm .
#
# > the process is feeding on itself and becoming , i guess , autocatalytic is the word for it -- when something reinforces its rate of change .
# = quá_trình này cứ tự nó tiếp_diễn và trở_nên , tôi đoán rằng , tự xúc_tác là từ thích_hợp - - khi một quá_trình_tự thúc_đẩy tốc_độ thay_đổi của nó .
# < và tôi đã làm .
#
# > it 's true .
# = thật đấy .
# < và nó là một người đã làm .
#
# > it 's been viewed nearly 50 million times this year .
# = video này đã có gần 50 triệu lượt xem vào năm nay .
# < và nó là một người đã làm .
#
# > which brings me to the second technique for handling the choice overload problem , which is concretization .
# = điều đó mnag cho tôi kĩ_thuật thứ hai trong việc giải_quyết vấn_đề quá_tải lựa_chọn mà rất cụ_thể
# < và tôi đã làm là một người khác .
#
# > now the question that i 'd like to ask is , if you look at these exponential curves , they don 't go on forever .
# = giờ câu hỏi tôi muốn đặt ra là , nếu bạn nhìn vào những đường_cong theo quy_luật số_mũ này , chúng không nhân lên mãi_mãi .
# < tôi đã làm là một người khác , tôi đã làm .
#
# > my mother was exhausted each night , but we told one another about our day and listened to the movements of my grandmother around the house .
# = mẹ tôi_tối nào cũng kiệt_sức , nhưng chúng_tôi kể cho nhau nghe chuyện trong ngày và nghe tiếng bà tôi đi_lại quanh nhà .
# < và tôi đã làm là một người khác .
#
# > and now i 'll give you a few seconds to read it and then i want you to clap your hands if you 're ready to take gary up on his offer .
# = bây_giờ tôi sẽ cho bạn vài giây để đọc nó sau đó tôi muốn bạn vỗ_tay nếu bạn sẵn_sàng nhận sự lời đề_nghị của gary
# < tôi đã làm là một người khác , tôi đã làm là một người khác , tôi đã làm .
#
# > she opened a computer store then studied to be a beautician and opened another business .
# = mẹ mở cửa_hàng máy_tính rồi học nghề chuyên_viên thẩm_mĩ và mở một cơ_sở kinh_doanh khác .
# < và tôi đã làm .
#
# > this is a generation that 's grown up taking their voices pretty much for granted .
# = đây là thế_hệ dùng tiếng_nói của mình để đấu_tranh cho quyền_lợi .
# < và tôi đã làm .
#
# > somebody broke in and they hacked it thoroughly .
# = ai đó đã xâm_nhập vào hệ_thống và phá_huỷ nó hoàn_toàn .
# < và nó là một người đã làm .
#
# > over here , these are the apsaras .
# = ở đây , đây là các nàng apsara .
# < và nó là một người đã làm .
#
# > now if i look at those programs , i can 't tell you how they work .
# = giờ nếu tôi nhìn vào những chương_trình ấy , tôi không_thể cho mọi người biết chúng hoạt_động như thế_nào .
# < tôi đã làm là một người khác , tôi đã làm .
#
# > so we talk about a 300 , a batter who bats 300 .
# = ví_dụ là số 300 nhé , một cầu_thủ đập bóng 300 .
# < và tôi đã làm .
#
# > huh . hang on a moment .
# = hở . xin chờ một_chút .
# < và nó là một người đã làm .
#
# > and then , so if you can just turn on the slide that 's on .
# = tiếp_theo , nếu bạn có_thể bật trang báo_cáo này lên .
# < và tôi đã làm là một người khác .
#
# > and so i did .
# = và thế_là tôi cố hoàn_hảo .
# < và tôi đã làm .
#
# > and i was shocked and shaken to the core .
# = và tôi bị sốc và run_rẩy tới tận xương .
# < tôi đã làm .
#
# > and to report back to my attending .
# = và báo_cáo lại với bác_sĩ giám_sát tôi .
# < và tôi đã làm .
#
# > this is the work of the very smart people at the office of new urban mechanics in boston .
# = đây là thành_quả của những con_người xuất_sắc tại văn_phòng cơ_học thành_phố tại boston .
# < và nó là một người đã làm .
#
# > i said , ' okay , mama . '
# = tôi đáp ' dạ được thôi ạ '
# < tôi đã làm .
#
# > and sometimes when it comes through ted , it has meaning and power that it doesn 't have when it doesn 't .
# = và đôi_khi bạn đến với ted nó mang lại ý_nghĩa và sức_mạnh cho bạn mà nếu_như bạn không đến bạn sẽ không có được sức_mạnh như_thế
# < và tôi đã làm là một người khác .
#
# > centers were established .
# = các trung_tâm được thành_lập .
# < và nó là một người đã làm .
#
# > that when we actually don 't care about these difficult things , the positive and wonderful things are nonetheless implicated .
# = khi chúng_ta không thực_sự quan_tâm đến những thứ khó_khăn thì những điều tốt_đẹp tuyệt_nhiên cũng bị ảnh_hưởng
# < và tôi đã làm là một người khác .
#
# > and an hour or two later , if i saw her , she 'd come over to me and she 'd say , ' bryan , do you still feel me hugging you ? '
# = một hoặc hai giờ sau , nếu tôi lại gặp bà bà sẽ tiến đến và nói : ' bryan à , con vẫn cảm_thấy như bà ôm con chứ ? '
# < và tôi đã làm là một người khác , tôi đã làm là một người khác , tôi đã làm là một người khác .
#
# > we had a team that worked on a project in boston last year that took three people about two and a half months .
# = năm_ngoái , chúng_tôi có một đội gồm ba người làm_việc trong một dự_án kéo_dài hai tháng rưỡi ở boston .
# < và tôi đã làm .
#
# > now i think that the reason is because we all feel that something 's happening there .
# = tôi nghĩ rằng lí_do của việc ấy là bởi tất_cả chúng_ta đều cảm_thấy việc gì đó đang diễn ra tại thời_điểm ấy .
# < tôi đã làm là một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một
#
# > because i have nothing to hide . '
# = tôi hoàn_toàn không có gì khuất_tất phải che dấu .
# < tôi đã làm .
#
# > and getting this idea during winter , i knew that i had several months to plan it , to find the different locations for the pieces of the puzzle basically .
# = và có được ý_tưởng này trong suốt mùa đông , tôi biết mình phải mất vài tháng để chuẩn_bị , để tìm các địa_điểm khác nhau cho các phần của bức ảnh .
# < và tôi đã làm , tôi đã làm .
#
# > baseball is filled with some amazing statistics .
# = môn bóng_chày đầy_rẫy những con_số thống_kê đáng kinh_ngạc .
# < và nó là một người đang làm .
#
# > photos like this : construction going on along a busy road .
# = những tấm ảnh như thế này : việc xây_dựng diễn ra dọc theo con đường đông_đúc .
# < và nó là một người đang làm .
#
# > but what 's important here is the creativity that it inspired amongst this techie , geeky internet culture .
# = nhưng điều quan_trọng ở đây là tính sáng_tạo mà nó truyền_cảm_hứng trong nền văn_hoá internet lạ_lùng này .
# < và tôi đã làm là một người khác .
#
# > if you do , you get to name it , and he called the first one al .
# = mỗi lần làm như_vậy , bạn phải đặt tên cho nó , và anh ấy đặt tên chiếc đầu_tiên là al .
# < và tôi đã làm là một người khác .
#
# > so for example , the invention of language was a tiny step in that direction .
# = ví_dụ như , sự phát_minh ra tiếng_nói là một bước_tiến nhỏ theo chiều_hướng ấy .
# < và nó là một người đã làm .
#
# > oh , that 's all my time ?
# = ồ , tôi hết giờ rồi sao ?
# < và tôi đã làm .
#
# > and that wasn 't a difficult diagnosis to make .
# = chẩn_đoán bệnh này không phải là khó .
# < và tôi đã làm .
#
# > the bottom is transformed from , in this case , a hard bottom or soft coral into a muddy mess .
# = đáy biển bị biến_dạng trong trường_hợp này từ đáy biển cứng hoặc san_hô mềm trở_thành một đống bùn hỗn_độn .
# < và tôi đã làm .
#
# > because with marine protected areas , we actually recreate the past .
# = vì với những vùng_biển được bảo_tồn như thế chúng_ta thực_sự đang tái_tạo lại quá_khứ
# < và tôi đã làm .
#
# > but i think that there really is something coming along after us .
# = nhưng tôi nghĩ rằng có một cái gì đó đang bám đuổi chúng_ta .
# < tôi đã làm .
#
# > you should ask for some of that .
# = thế_thì mình nên xin họ một_chút .
# < và tôi đã làm .
#
# > we 're trying to confront bias and discrimination in the administration of criminal justice .
# = cố_gắng đương_đầu với sự thiên_vị và phân_biệt xử trong cách xét_xử tư_pháp ,
# < và tôi đã làm .
#
# > and they actually illuminate your way through the rest of the book .
# = và chúng sẽ chiếu sáng cho bạn qua phần còn lại của quyển sách .
# < và tôi đã làm .
#
# > now i design computers for a living , and i know that the mechanisms that i use to design computers would be impossible without recent advances in computers .
# = giờ tôi thiết_kế máy_tính để kiếm tiền , và tôi biết rằng thiết_bị tôi dùng để thiết_kế máy_tính có_thể không sử_dụng được nếu không có những công_nghệ gần đây trong ngành máy_tính .
# < tôi đã làm , tôi đã làm .
#
# > but combined in a certain way , they can create something that still looks three-dimensional , like it could exist .
# = nhưng kết_hợp theo một_cách nào đấy , chúng tạo ra một thứ mà trông vẫn như_thể ba chiều , như_thể nó tồn_tại .
# < và tôi đã làm là một người khác .
#
# > how can a judge turn you into something that you 're not ?
# = sao một quan toà có_thể biến bạn thành một người mà bạn vốn không phải ?
# < và tôi đã làm là một người khác .
#
# > then she said , ' the second thing i want you to promise me is that you 'll always do the right thing even when the right thing is the hard thing . '
# = ' điều thứ 2 bà muốn con hứa là sẽ luôn làm những việc đúng_đắn dẫu có khó_khăn đến mấy ' .
# < tôi đã làm là một người khác , tôi đã làm là một người khác .
#
# > what do you do with certificates ?
# = bạn sẽ làm gì với những chứng_chỉ đó ?
# < và tôi đã làm .
#
# > and they noticed that the city never gets to digging out these fire hydrants .
# = họ để_ý rằng thành_phố không bao_giờ tháo bỏ những vòi_nước chữa_cháy .
# < và tôi đã làm .
#
# > so it says , ' place your fingers upon each light . '
# = ở đây nói là , ' hãy đặt tay bạn lên mỗi cái đèn , '
# < và tôi đã làm .
#
# > it would be unconscionable for us to , in an intentional and deliberate way , set about executing people . '
# = việc_làm đó thật vô_lương_tâm dù vô_tình hay cố_ý cũng không nên tử_hình ai đó '
# < và tôi đã làm .
#
# > one of the interactions in the book is that you 're sent off on this quest where you need to go outside , take out your camera on the ipad and collect pictures of different natural objects .
# = một trong những hoạt_động tương_tác trong quyển sách là bạn được cử đi một chuyến hành_trình tìm_kiếm trong đó bạn phải đi ra ngoài dùng máy_ảnh của ipad và chụp ảnh của các vật_thể tự_nhiên khác nhau .
# < và tôi đã làm là một người khác .
#
# > the other way of thinking about it is not , do people deserve to die for the crimes they commit , but do we deserve to kill ?
# = cách nghĩ khác về điều này không phải là liệu người có tội có đáng chết hay không mà liệu chúng_ta có quyền giết họ hay không ?
# < và tôi đã làm là một người khác .
#
# > and we 're not going to fix government until we fix citizenship .
# = và chúng_ta không_thể ổn_định chính_phủ cho đến khi chúng_ta làm tốt nhiệm_vụ công_dân .
# < và tôi đã làm là một người khác .
#
# > he said , ' what 's wrong with you ? have some beer . '
# = và nói ' em bị làm_sao vậy ? uống tí đi '
# < và tôi đã làm là một người khác .
#
# > the main reason for this is because , we might enjoy gazing at those giant walls of mayonnaises , mustards , vinegars , jams , but we can 't actually do the math of comparing and contrasting and actually picking from that stunning display .
# = lý_do chính ở đây là bởi gì chúng_ta có_thể yêu thích nhìn vào những bức tường to_lớn của sốt_ma - yo , mù tạc , giấm , mứt nhưng chúng_ta không_thể thực_hiện bài_toán của sự so sách và sự tương_phản và thậm_chí từ sự cho thấy ngạc_nhiên
# < và tôi đã làm là một người khác , và tôi đã làm là một người khác .
#
# > i gave her my whole rap , and when i finished she looked at me and she said , ' mmm mmm mmm . '
# = khi tôi nói hết_ý của mình , bà ấy nhìn tôi và nói ' ừm , ừm , ừm '
# < tôi đã làm là một người khác , tôi đã làm .
#
# > and so i want to talk about the power of identity .
# = đó là lý_do tại_sao tôi muốn nói về sức_mạnh của bản_sắc nhân_cách
# < tôi đã làm .
#
# > so it 's got cute little game dynamics on it .
# = vậy là có chút động_lực cho việc này .
# < và tôi đã làm .
#
# > i personally think that it 's easier to actually create a place than to find a place , because then you don 't need to compromise with the ideas in your head .
# = cá_nhân tôi nghĩ rằng sẽ dễ hơn để thậm_chí tạo ra bối_cảnh hơn là tìm ra bối_cảnh , vì tiếp đó bạn không cân phải sắp_xếp các ý_tưởng trong đầu nữa .
# < tôi đã làm là một người khác , tôi đã làm .
#
# > and i claim it 's already today that it 's more likely for any of us to become the victim of a crime online than here in the real world .
# = và tôi khẳng_định rằng ngày_nay nguy_cơ_mà chúng_ta trở_thành nạn_nhân của tội_phạm mạng còn lớn hơn nguy_cơ trong thế_giới thực này .
# < tôi đã làm là một người khác , tôi đã làm .
#
# > and it wasn 't because of my attending ; he was a doll .
# = và không phải vì bác_sĩ hướng_dẫn của tôi ; anh ấy dễ mến vô_cùng .
# < và tôi đã làm là một người khác .
#
# > now we didn 't write this app .
# = chúng_tôi không viết ứng_dụng này .
# < và tôi đã làm .
#
# > so we 're beginning to depend on computers to do a process that 's very different than engineering .
# = vì_vậy , chúng_ta bắt_đầu phụ_thuộc vào máy_tính để thực_hiện một quá_trình khác_biệt hơn hẳn với thiết_kế xây_dựng .
# < và tôi đã làm .
#
# > and those that were like that started to split and divide .
# = và những giọt dầu như thế bắt_đầu tách ra và phân_chia .
# < và tôi đã làm .
#
# > good , really good , maybe an all-star .
# = tốt , cực tốt , có_thể là siêu_sao .
# < và tôi đã làm .
#
# > or photos like these -- both dark and colorful , but all with a common goal of retaining the level of realism .
# = hay những bức ảnh như thế này - - cả tối màu và sặc_sỡ , nhưng tất_cả với chung một kết_quả của việc lưu_giữ mức_độ chân_thực .
# < và tôi đã làm .
#
# > it was busy , i was in a bit of a hurry .
# = lúc ấy rất bận_rộn , tôi đang hơi vội .
# < tôi đã làm .
#
# > and it all connects us together into something that is much bigger and much faster and able to evolve than what we were before .
# = và chúng đều liên_kết chúng_ta thành một cộng_đồng lớn hơn nhanh hơn và có khả_năng tiến_hoá xa hơn chúng_ta trước đây .
# < và tôi đã làm là một người khác .
#
# > if i start you off easy , i learn how to choose .
# = nếu tôi bắt_đầu với bạn dễ_dàng , tôi học làm thế_nào lựa_chọn .
# < tôi đã làm .
#
# > ' do you remember that patient you sent home ? '
# = ' anh có nhớ bệnh_nhân anh cho xuất_viện không ? '
# < tôi đã làm là một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một người có một
#
# > they were there in february , and it snowed a lot in february last year .
# = họ ở đó trong tháng hai đầy tuyết .
# < và tôi đã làm .
#
# > and at about the nine day mark , they let her go -- mrs. drucker , a wife , a mother and a grandmother .
# = và sau khoảng chín ngày , họ để bà ra đi - - bà drucker , người vợ , người mẹ , và người bà .
# < và tôi đã làm .
#
# > he said , ' i 'm so proud of you . '
# = ông nói : ' tôi rất tự_hào về cậu '
# < tôi đã làm là một người khác , tôi đã làm .
#
# > and on a cloudy day , there was a crack in the clouds and the sun started to come out and i wondered , maybe i could feel better again .
# = và trong một ngày nhiều mây , có khe hở giữa các đám mây và mặt_trời ló dạng và tôi thắc_mắc , chắc là tôi có_thể cảm_thấy khá hơn một lần nữa .
# < và tôi đã làm là một người khác , tôi đã làm .
#
# > so we 've all heard about fairies and we 've all heard about nymphs , but how many people outside of india know about their indian counterparts , the apsaras ?
# = chúng_ta đều đã nghe kể về các nàng tiên , chúng_ta đều đã nghe kể về các nữ_thần , nhưng có mấy ai không ở ấn độ mà_lại biết về phiên_bản ấn độ , các nàng apsara ?
# < và tôi đã làm là một người khác .
#
# > you can go on the website , download all the design files , make them yourself .
# = bạn có_thể lên trang_web , tải về những file thiết_kế và tự làm chúng .
# < và tôi đã làm là một người khác .
#
# > so in other words , the future has kind of been shrinking one year per year for my whole lifetime .
# = vì_vậy , nói cách khác , tương_lai dường_như chùn lại một năm mỗi năm cho cả đời người .
# < và tôi đã làm .
#
# > and a story that actually deals with new issues like the environmental crisis .
# = và một câu_chuyện còn phản_ánh những vấn_đề mới như là vấn_nạn môi_trường .
# < và nó là một người khác .
#
# > today , there are 2.3 million .
# = ngày_nay , con_số đó đã lên đến 2,3 triệu
# < và nó là một người đã làm .
#
# > when i would see her as a little boy , she 'd come up to me and she 'd give me these hugs .
# = khi tôi còn bé , mỗi khi tôi nhìn bà bà sẽ đến bên và ôm tôi vào lòng
# < tôi đã làm là một người khác , tôi đã làm .
#
# > so now for the topic of today : financial savings .
# = chủ_đề hôm_nay sẽ tiếp_tục với : tiết_kiệm tài_chính
# < và nó là một người đã làm .
#
# > i was in the desert , under the starry skies with the sufi singer mukhtiar ali .
# = lúc đó tôi đang ở trong sa_mạc , dưới bầu_trời sao cùng ca_sĩ theo đạo sufi , mukhtiar ali .
# < tôi đã làm .
#
# > so beyond simple play , littlebits are actually pretty powerful .
# = như các bạn đã thấy , không chỉ đơn_giản để chơi littlebits còn tỏ ra là một công_cụ mạnh .
# < và nó là một người đã làm .
#
# > in both cases , these are gross underestimates , because we really aren 't ferreting out the problem as we should .
# = trong cả hai trường_hợp , đây đều là những ước đoán quá thấp so với thực_tế , bởi_vì thực_tế ta chưa từng truy_tìm kĩ vấn_nạn này mà đáng_lẽ chúng_ta phải như thế .
# < và tôi đã làm là một người khác .
#
# > and if you think that that is weird , you should know that there is a three-hour version of this that 's been viewed four million times .
# = và nếu bạn nghĩ điều này thật kỳ_quặc , bạn nên biết rằng có một phiên_bản 3 giờ của nó nhận được 4 triệu lượt xem .
# < và tôi đã làm là một người khác .
#
# > but i think that there really is something coming along after us .
# = nhưng tôi nghĩ rằng có một cái gì đó đang bám đuổi chúng_ta .
# < tôi đã làm .
#
# > now the question that i 'd like to ask is , if you look at these exponential curves , they don 't go on forever .
# = giờ câu hỏi tôi muốn đặt ra là , nếu bạn nhìn vào những đường_cong theo quy_luật số_mũ này , chúng không nhân lên mãi_mãi .
# < tôi đã làm là một người khác , tôi đã làm .
#
# > and yet , we have in this country this dynamic where we really don 't like to talk about our problems .
# = chúng_ta thấy được thực_trạng này nhưng chúng_ta lại không muốn bàn về vấn_đề của chính mình
# < và tôi đã làm là một người khác , tôi đã làm .
#
# > for her , life had distilled itself into one task : the escape of her family and a new life in australia .
# = với mẹ , cuộc_đời cô_đọng vào nhiệm_vụ duy_nhất : để gia_đình mẹ trốn thoát và bắt_đầu cuộc_sống mới ở úc .
# < và nó là một người đã làm .
#
# > the child in me is really excited by these kinds of possibilities .
# = đứa trẻ trong tôi vô_cùng hứng_thú bởi những khả_năng như thế này .
# < và tôi đã làm .
#
# > let 's say i want to sort numbers , as a simple example i 've done it with .
# = khi tôi muốn sắp_xếp các số , một ví_dụ đơn_giản mà tôi thực_hiện được .
# < tôi đã làm là một người khác , tôi đã làm .
#
# > but then what happened was the individuals worked out , of course , tricks of communicating .
# = nhưng sau đó điều xảy ra là các cá_thể_hình_thành nên đương_nhiên rồi , những mánh_khoé trong việc trao_đổi thông_tin .
# < và tôi đã làm .
#
# > and if i said , ' no , ' she 'd assault me again , and if i said , ' yes , ' she 'd leave me alone .
# = và nếu tôi nói ' dạ không ' , bà sẽ lại ' tấn_công ' tôi và nếu tôi nói ' dạ có ' , bà sẽ để tôi một_mình .
# < và tôi đã làm là một người khác , tôi đã làm là một người khác , tôi đã làm .
#
# > and over time it changes -- it changes because people do things , or naturally .
# = theo thời_gian nó sẽ thay_đổi - - nó thay_đổi do con_người làm điều gì đó tác_động hay do tự_nhiên
# < và tôi đã làm .
#
# > her father died soon after she was born .
# = ba của bà mất ngay sau khi bà ra_đời .
# < và nó là một người đã làm .
#
# > so for my first question for you today : are you guys ready to hear about the choice overload problem ?
# = giờ là câu hỏi đầu_tiên của ngày hôm_nay , bạn có sẵn_sàng để nghe về vấn_đề quá_tải trong lựa_chọn ?
# < và tôi đã làm là một người khác .
#
# > well every one of those generations just takes a few milliseconds .
# = tất_cả mọi cá_nhân trong thế_hệ mới đều chỉ mất vài mili - giây .
# < và tôi đã làm .
#
# > and these scientists simply documented all the various tasks that these ceos engaged in and how much time they spent engaging in making decisions related to these tasks .
# = và những nhà khoa_học đã dẫn ra tất_cả những nhiệm_vụ khác nhau mà những ceo đó tham_gia và họ đã tốn bao nhiều thời_gian để thực_hiện những quyết_định liên qua đén những nhiệm_vụ đó
# < và tôi đã làm là một người khác .
#
# > if you do , you get to name it , and he called the first one al .
# = mỗi lần làm như_vậy , bạn phải đặt tên cho nó , và anh ấy đặt tên chiếc đầu_tiên là al .
# < và tôi đã làm là một người khác .
#
# > so i 'm just going to enter in .
# = thế , tôi sẽ đi vào bây_giờ .
# < tôi đã làm .
#
# > and actually i become a character in the book .
# = và trên thực_tế tôi biến thành một nhân_vật trong quyển sách .
# < và tôi đã làm .
#
# > it was a way that parents could figure out which were the right public schools for their kids .
# = dự_án giúp cha_mẹ tìm_kiếm trường công_lập phù_hợp với con_cái mình .
# < và tôi đã làm .
#
# > speaking of the environmental crisis , i think a big problem has been in the last 10 years is that children have been locked inside their rooms , glued to their pcs , they haven 't been able to get out .
# = tiện_thể nói về vấn_nạn môi_trường , tôi nghĩ một vấn_đề lớn trong 10 năm gần đây là các em nhỏ đã bị nhốt trong phòng , dán mắt vào màn_hình máy_tính , các em không ra ngoài chơi được .
# < tôi đã làm là một người khác , tôi đã làm .
#
# > and i was up too late one night and i starting thinking , well gosh , if the judge can turn you into something that you 're not , the judge must have magic power .
# = và có một đêm , tôi thức rất khuya và bắt_đầu nghĩ lạ nhỉ , nếu quan toà có_thể làm vậy thì hẳn là họ có quyền_lực vô_biên
# < tôi đã làm là một người khác , tôi đã làm là một người khác , tôi đã làm .
#
# > an entire remix community sprouted up that brought it from being just a stupid joke to something that we can all actually be a part of .
# = một cộng_đồng phối_khí nổi lên biến nó tự một trò_đùa ngu_ngốc đến điều gì đó mà tất_cả chúng_ta có_thể là một phần trong đó .
# < và tôi đã làm là một người khác .
#
# > and i memorized everything .
# = và tôi thuộc_làu mọi thứ .
# < tôi đã làm .
#
# > now truth of the matter is , nobody knows in all of medicine what a good surgeon or physician or paramedic is supposed to bat .
# = nhưng trên thực_tế không ai biết trong cả nền y_khoa một bác_sĩ phẫu_thuật tốt hay một y_sĩ phải cần ' đập ' quả bóng nào .
# < và tôi đã làm .
#
# > mr. jain himself is on the loose ; nobody knows where he is .
# = jain hiện đang lẩn_trốn ; và không ai biết anh ta đang ở đâu .
# < và nó là một người đã làm .
#
# > and my small startup is looking to force ourselves into the environment by paying attention to ...
# = và công_ty nhỏ mới thành_lập của tôi đang cố_gắng thâm_nhập vào môi_trường bằng cách chú_ý tới ...
# < và tôi đã làm .
#
# > and finally , he says , ' look , can you just open all the doors to your house and play music really loud and see if the thing leaves ? '
# = cuối_cùng , anh ấy nói : ' nhìn xem , chẳng phải bạn có_thể mở tất_cả cánh cửa tới nhà bạn và chơi nhạc thật to và nhìn xem có thứ gì chuyển_động ko ? '
# < và tôi đã làm là một người khác , tôi đã làm .
#
# > and i was catapulted from one piece of the jigsaw to another , and their edges didn 't fit .
# = và tôi bị phóng từ mảnh ghép xếp hình này sang mảnh khác , nhưng chúng không ghép vừa với nhau .
# < tôi đã làm .
#
# > somehow this isn 't working .
# = rõ là thế này vẫn chưa ổn .
# < và tôi đã làm .
#
# > this was my first sunburn .
# = đây là vết rám nắng đầu_tiên của tôi
# < và tôi đã làm .
#
# > a few years ago i started developing littlebits .
# = một_vài năm trước tôi đã bắt_đầu phát_triển littlebits .
# < tôi đã làm .
#
# > so we 've all heard about fairies and we 've all heard about nymphs , but how many people outside of india know about their indian counterparts , the apsaras ?
# = chúng_ta đều đã nghe kể về các nàng tiên , chúng_ta đều đã nghe kể về các nữ_thần , nhưng có mấy ai không ở ấn độ mà_lại biết về phiên_bản ấn độ , các nàng apsara ?
# < và tôi đã làm là một người khác .
#
# > i 'm going to tell you something i probably shouldn 't .
# = mà đáng_lý tôi không nên nói ra
# < tôi đã làm là một người khác , tôi đã làm .
#
# > and i thought i could blend in .
# = mặc_dù tôi đã có_thể hoà_nhập với cuộc_sống tại đó
# < tôi đã làm .
#
# > say , ' please repeat that process . '
# = tôi nói với máy_tính , ' hãy lặp lại quá_trình . '
# < và tôi đã làm .
#
# > let me show you how they work .
# = để tôi cho bạn thấy chúng hoạt_động ra sao .
# < tôi đã làm là một người khác .
#
# > if you generalize this , something like this happens .
# = nếu bạn khái_quát_hoá điều này , điều gì đó giống như thế này sẽ xảy đến
# < và tôi đã làm là một người khác .
#
# > and when i listened to her chest with a stethoscope , i could hear crackly sounds on both sides that told me that she was in congestive heart failure .
# = và khi tôi nghe lồng_ngực của bà bằng ống_nghe , tôi có_thể nghe thấy tiếng lách_tách ở cả hai bên cho thấy là bà bị suy tim do tắc_nghẽn .
# < tôi đã làm là một người khác , tôi đã làm .
#
# > if you are a suspect in a criminal case , well it 's pretty obvious , your phone will be tapped .
# = nếu bạn đang bị nghi_ngờ có dính_líu đến một tội_ác nào đó , thì điều chắc_chắn là điện_thoại của bạn đang có ' rệp ' .
# < và tôi đã làm là một người khác .
#
# > people seem to think politics is sexy .
# = có người cho rằng chính_trị rất hấp_dẫn .
# < và nó là một người đã làm .
#
# > the process is feeding on itself and becoming , i guess , autocatalytic is the word for it -- when something reinforces its rate of change .
# = quá_trình này cứ tự nó tiếp_diễn và trở_nên , tôi đoán rằng , tự xúc_tác là từ thích_hợp - - khi một quá_trình_tự thúc_đẩy tốc_độ thay_đổi của nó .
# < và tôi đã làm .
#
# > and so over here you need to tilt your ipad , take the fireflies out .
# = và thế_là ở đây , bạn cần nghiêng ipad , để lấy đom_đóm ra .
# < và tôi đã làm là một người khác .
#
# > but where would be the nearest aed to help this patient ?
# = nhưng ở đâu có thiết_bị aed gần nhất để có_thể giúp bệnh_nhân này ?
# < và tôi đã làm .
#
# > what does it mean ?
# = điều này có_nghĩa gì ?
# < và nó là một người đã làm .
#
# > this is a highly useless categorization scheme .
# = đây là sự sắp_xếp rất vô_ích .
# < và nó là một người đã làm .
#
# > imagine him as the communists enter saigon , confronting the fact that his life had been a complete waste .
# = hãy tưởng_tượng ông , một người cộng_sản tiến vào sài_gòn , đối_diện sự_thật rằng cả cuộc_đời ông đã phí_hoài .
# < và tôi đã làm .
#
# > in fact , every living creature is written in exactly the same set of letters and the same code .
# = thực_tế , mọi sinh_vật sống đều được lưu_trữ cấu_tạo gen của nó bằng hệ_thống kí_tự và mật_mã hoàn_toàn tương_tự .
# < và nó là một người khác .
#
# > and because the idea can be explained in one minute , i will tell you three stories before to fill in the time .
# = và vì ý_tưởng đó có_thể được giải_thích trong vòng 1 phút . tôi sẽ kể cho các bạn 3 câu_chuyện trước để lấp vào thời_gian còn thừa .
# < và tôi đã làm là một người khác , tôi đã làm .
#
# > one method that 's particularly interesting that i 've been using a lot lately is evolution itself .
# = một phương_pháp đặc_biệt thú_vị mà tôi hiện vẫn đang dùng nhiều là bản_thân sự tiến_hoá
# < tôi đã làm .
#
# > we want to make every single interaction in the world into a ready-to-use brick .
# = chúng_tôi muốn tích_hợp mọi tương_tác trên thế_giới vào những ' viên gạch ' có_thể sử_dụng dễ_dàng .
# < và tôi đã làm .
#
# > introduce some mutations perhaps .
# = có_thể đưa ra vài sự hoán_đổi .
# < và nó là một người đã làm .
#
# > hey , why not ?
# = ồ , tại_sao không ?
# < và nó là một người đã làm .
#
# > but they do the job .
# = nhưng chúng thực_hiện được công_việc .
# < và tôi đã làm .
#
# > my first memories are from the boat -- the steady beat of the engine , the bow dipping into each wave , the vast and empty horizon .
# = kí_ức sớm nhất tôi nhớ được là từ cái thuyền - - tiếng_động_cơ đều đều , mạn tiền con thuyền chìm vào mỗi đợt sóng , chân_trời mênh_mông trống_trải .
# < và tôi đã làm .
#
# > and over the course of the next eight or nine days , they resigned themselves to what was happening .
# = và trong vòng tám hay chín ngày tiếp_theo , họ đầu_hàng số_phận .
# < và tôi đã làm .
#
# > we 're taking off .
# = chúng_ta đang cất_cánh .
# < và nó là một người khác .
#
# > or photos like these -- both dark and colorful , but all with a common goal of retaining the level of realism .
# = hay những bức ảnh như thế này - - cả tối màu và sặc_sỡ , nhưng tất_cả với chung một kết_quả của việc lưu_giữ mức_độ chân_thực .
# < và tôi đã làm .
#
# > and it could have connected them with government services if they 'd been needed , but a neighbor is a far better and cheaper alternative to government services .
# = nếu cần_thiết , các dịch_vụ của chính_phủ có_thể giúp_đỡ họ kết_nối lại , nhưng một người hàng_xóm thì là một giải_pháp tốt và tiết_kiệm hơn so với các dịch_vụ của chính_phủ .
# < và tôi đã làm .
#
# > because tastemakers like jimmy kimmel introduce us to new and interesting things and bring them to a larger audience .
# = bởi_vì những người tạo ra trào_lưu như jimmy kimmel giới_thiệu cho chúng_ta những điều mới_lạ và thú_vị cũng như đưa những điều đó đến một lượng khán_giả lớn hơn .
# < và tôi đã làm .
#
# > another idea that really fascinated me as a child was that an entire galaxy could be contained within a single marble .
# = một ý_tưởng khác hớp_hồn tôi khi còn bé là nguyên một thiên_hạ rộng_lớn có_thể bị thu vào một hòn bi duy_nhất .
# < tôi đã làm là một người khác .
#
# > so what happened on this day ?
# = vậy điều gì xảy ra vào ngày này ?
# < và nó là một người đã làm .
#
# > we 're bringing our children and ourselves closer to the natural world and that magic and joy and childhood love that we had through the simple medium of a story .
# = chúng_ta đang đưa con_em ta và chính chúng_ta lại gần hơn với thế_giới tự_nhiên và cái phép màu và niềm vui và niểm yêu_mến trẻ_thơ ta có qua phương_tiện đơn_giản là một câu_chuyện .
# < và tôi đã làm .
#
# > because i was there in ' 71 , studying a lagoon in west africa .
# = cười tôi đã đến đó vào năm 1971 , nghiên_cứu đầm_phá ở tây phi
# < tôi đã làm .
#
# > and if you think about ' avatar , ' if you think of why people were so touched by it -- never mind the pocahontas story -- why so touched by the imagery ?
# = cười nếu bạn nghĩ đến phim ' avata ' nếu bạn nghĩ về việc mọi nó đã lay_động mọi người như thế_nào - - đừng để_ý đến câu_chuyện pocahontas làm gì - - tại_sao lại bị lay_động bởi biểu_tượng đến thế
# < và tôi đã làm là một người khác .
#
# > you have on the y axis some good thing : biodiversity , numbers of orca , the greenness of your country , the water supply .
# = chúng_ta có một_vài điều tốt từ trục y ở đây sự đa_dạng sinh_học , số_lượng của cá_voi sát_thủ diện_tích rừng của đất_nước bạn , nguồn cung_cấp_nước .
# < và tôi đã làm .
#
# > and so -- it says , ' this box belongs to ... ' and so i type in my name .
# = và thế_là - - nó nói , ' quyển sách này là của ... ' và thế_là tôi gõ tên tôi vào .
# < và tôi đã làm là một người khác , tôi đã làm .
#
# > and then it happened again .
# = và điều đó lại xảy ra .
# < và nó là một người khác .
#
# > these might be courier services or cable guys for instance , just to see whether the aed that 's submitted still is in place .
# = các công_ty này có_thể là dịch_vụ chuyển_phát nhanh hay dịch_vụ cáp điện_thoại chẳng_hạn , chỉ để chắc rằng những thiết_bị aed được gửi thông_tin về vẫn còn ở chỗ đó .
# < và tôi đã làm .
#
# > ohhhh .
# = ohhh .
# < và nó là một người đã làm .
#
# > this idea of fireflies in a jar , for some reason , was always really exciting to me .
# = ý_tưởng nhốt đom_đóm trong lọ thuỷ_tinh , không biết tại_sao , luôn vô_cùng thú_vị đối_với tôi .
# < và tôi đã làm .
#
# > i began to feel a bit better .
# = tôi bắt_đầu thấy khá hơn một_chút .
# < tôi đã làm .
#
# > and i mention that because i think identity is really important .
# = và tôi đề_cập đến điều này bởi tôi nghĩ bản_sắc thực_sự rất quan_trọng
# < tôi đã làm , tôi đã làm .
#
# > the third one is about making it impossible to distinguish where the different images begin and end by making it seamless .
# = nguyên_tắc thứ ba là làm cho nó trông thật giả_tưởng ở ngay nơi mà những bức ảnh khác nhau bắt_đầu và kết_thúc bằng cách làm cho chúng liền mạch .
# < và nó là một người đã làm .
#
# > another thing that 's actually really important to me is creating content that is indian and yet very contemporary .
# = một điều thật_sự quan_trọng nữa đối_với tôi là việc tạo ra nội_dung thật_sự ấn độ nhưng vẫn hiện_đại .
# < tôi đã làm là một người khác .
#
# > among those papers , was this binder entitled ' finfisher . '
# = trong đó , có tập tài_liệu được đánh_dấu ' finfisher '
# < và tôi đã làm .
#
# > so you don 't lose abundant animals .
# = vậy nên bạn không mất đi những động_vật với số_lượng phong_phú
# < và tôi đã làm .
#
# > ohhhh .
# = ohhh .
# < và nó là một người đã làm .
#
# > something really weird is going on here .
# = có cái gì đó kỳ_quặc ở đây .
# < và tôi đã làm .
#
# > i 've come to ted because i believe that many of you understand that the moral arc of the universe is long , but it bends toward justice .
# ...
#
# > it 's not really what is realistic , it 's what we think looks realistic really .
# = nó không thực_sự là cái gì là thực , nó là cái chúng_ta nghĩ rằng nó là thực .
# < tôi đã làm là một người khác .
#
# > so scott gets this call .
# = scott nhận_thức được điều này .
# < và nó là một người đã làm .
#
# > we worked well into each night .
# = chúng_tôi làm_việc đến đêm khuya .
# < và tôi đã làm .
#
# > and during the break there was a deputy sheriff who was offended that the janitor had come into court .
# = trong lúc giải_lao , phó_quận trưởng cảnh_sát thấy bị xúc_phạm vì người canh_gác bước vào phòng xử án .
# < và tôi đã làm .
#
# > now this store , it was almost like going to an amusement park .
# = bây_giờ , nó gần như trở_thành_công_viên giải_trí .
# < và tôi đã làm .
#
# > they 're pre-engineered to be light , sound , motors and sensors .
# = chúng đã được thiết_kế sẵn để trở_thành ánh_sáng , âm_thanh , động_cơ và cảm_biến .
# < và tôi đã làm .
#
# > suppose you have appendicitis and you 're referred to a surgeon who 's batting 400 on appendectomies .
# = giả_dụ bạn bị viêm ruột_thừa và bạn được đưa tới một bác_sĩ giải_phẫu với chỉ_số phẫu_thuật ruột_thừa là 400 .
# < và tôi đã làm là một người khác .
#
# > it was not drowned yet .
# = nó vẫn chưa bị ngộp
# < và tôi đã làm .
#
# > as you can see , these images aren 't really special .
# = như các bạn thấy ở đây , những bức ảnh này trông chẳng có gì là đặc_biệt .
# < và tôi đã làm là một người khác .
#
# > cats were watching other cats watch this video .
# = những con mèo đang xem những con mèo khác xem video này .
# < và nó là một người đang làm .
#
# > so what happens here ?
# = vậy thì điều gì xảy ra tại đây ?
# < và nó là một người đã làm .
#
# > now that 's why , for instance , antibiotic resistance has evolved .
# = bởi vì_vậy_mà , ví_dụ , sự kháng thuốc kháng_sinh được hình_thành .
# < và tôi đã làm .
#
# > it brings together image and text and animation and sound and touch .
# = nó kết_hợp hình_ảnh , chữ , minh_hoạ động , âm_thanh , và cảm_giác chạm .
# < và nó là một người đã làm .
#
# > and what i 've learned is that errors are absolutely ubiquitous .
# = và điều tôi học được là sai_sót có_mặt khắp nơi .
# < tôi đã làm .
#
# > i think if somebody takes something that doesn 't belong to them , they 're not just a thief .
# = nếu ai lấy một món đồ gì mà không thuộc quyền sở_hữu của họ , họ không chỉ là một tên trộm .
# < tôi đã làm là một người khác , tôi đã làm .
#
# > he said , ' what 's wrong with you ? have some beer . '
# = và nói ' em bị làm_sao vậy ? uống tí đi '
# < và tôi đã làm là một người khác .
#
# > and they did .
# = và tiếng đó dừng thật .
# < và nó là một người khác .
#
# > in the ' 70s -- well , beginning in the ' 60s -- europe did lots of development projects .
# = trong những năm 70 - - , à không , bắt_đầu_từ những năm 60 - - châu âu thực_hiện rất nhiều các dự_án phát_triển
# < và tôi đã làm .
#
# > we adjust our baseline to the new level , and we don 't recall what was there .
# = chúng_ta điều_chỉnh đường mốc_giới của chính mình lên một cấp_độ mới mà chúng_ta chẳng nhớ trước_kia nó như thế_nào .
# < và tôi đã làm là một người khác .
#
# > then she said , ' the second thing i want you to promise me is that you 'll always do the right thing even when the right thing is the hard thing . '
# = ' điều thứ 2 bà muốn con hứa là sẽ luôn làm những việc đúng_đắn dẫu có khó_khăn đến mấy ' .
# < tôi đã làm là một người khác , tôi đã làm là một người khác .
#
# > one might think that this is just an image of a landscape and the lower part is what 's manipulated .
# = ai đó có_thể nghĩ rằng đây chỉ là bức ảnh phong_cảnh và phần ở dưới đã được chỉnh_sửa .
# < và tôi đã làm .
#
# > so one citizen helped another citizen , but government played a key role here .
# = mọi người giúp_đỡ lẫn nhau , nhưng chính_phủ đóng vai_trò cốt_lõi ở đây .
# < và tôi đã làm .
#
# > people are always upset when i say , ' cut . '
# = mọi người luôn_luôn lúng_túng khi tôi nói , ' cắt_giảm '
# < tôi đã làm là một người khác , tôi đã làm .
#
# > she was the beginning of a lot of arguments in our family .
# = và cũng luôn là người khơi nên nhiều cuộc tranh_cãi trong gia_đình
# < và tôi đã làm .
#
# > and those are the neural structures .
# = và đó là những cấu_trúc thần_kinh .
# < và nó là một người khác .
#
# > so what happened on this day ?
# = vậy điều gì xảy ra vào ngày này ?
# < và nó là một người đã làm .
#
# > and it wasn 't because of my attending ; he was a doll .
# = và không phải vì bác_sĩ hướng_dẫn của tôi ; anh ấy dễ mến vô_cùng .
# < và tôi đã làm là một người khác .
#
# > we have our cognitive biases , so that i can take a perfect history on a patient with chest pain .
# = chúng_ta có những định_kiến dựa vào kinh_nghiệm sẵn có , ví_dụ tôi có_thể chấp_nhận là một bệnh_nhân đau ngực có tiền_sử bệnh hoàn_hảo .
# < tôi đã làm là một người khác , tôi đã làm .
#
# > but now web video has made it so that any of us or any of the creative things that we do can become completely famous in a part of our world 's culture .
# = nhưng bây_giờ , các video trên web đã làm được điều đó để bất_cứ ai trong chúng_ta hay bất_cứ sản_phẩm sáng_tạo nào mà chúng_ta làm ra có_thể trở_nên hoàn_toàn nổi_tiếng trong một khu_vực văn_hoá của thế_giới chúng_ta .
# < và tôi đã làm là một người khác .
#
# > she took me out back and she said , ' bryan , i 'm going to tell you something , but you don 't tell anybody what i tell you . '
# = bà dẫn tôi ra khỏi phòng , ra phía sau nhà và nói ' bryan này , bà sẽ nói với con một chuyện nhưng con đừng nói với ai nhé '
# < tôi đã làm là một người này , tôi đã làm là một người khác , tôi đã làm là một người khác .
#
# > these might be courier services or cable guys for instance , just to see whether the aed that 's submitted still is in place .
# = các công_ty này có_thể là dịch_vụ chuyển_phát nhanh hay dịch_vụ cáp điện_thoại chẳng_hạn , chỉ để chắc rằng những thiết_bị aed được gửi thông_tin về vẫn còn ở chỗ đó .
# < và tôi đã làm .
#
# > the first : cut .
# = đầu_tiên : cắt_giảm
# < và một người đã làm .
#
# > she grew up at a time when confucianism was the social norm and the local mandarin was the person who mattered .
# = bà lớn lên trong thời_kì mà đạo khổng là chuẩn_mực xã_hội và quan lại địa_phương có quyền sinh quyền sát .
# < và nó là một người đã làm .
#
# > in urban communities across this country -- los angeles , philadelphia , baltimore , washington -- 50 to 60 percent of all young men of color are in jail or prison or on probation or parole .
# = ở những thành_phố lớn trên đất_nước này như los angeles , philadelphia , baltimore , washington có đên 50 - 60 % người da_màu đang trong tình_trạng tương_tự , họ bị tù , bị quản_chế hoặc tạm tha
# < và nó là một người đã làm .
#
# > privacy is implied .
# = quyền riêng_tư phải được đảm_bảo .
# < và nó là một người đã làm .
#
# > we have life imprisonment without parole for kids in this country .
# = chúng_ta có án tù chung_thân không hề đặc_xá cho trẻ_em
# < và tôi đã làm .
#
# > so to make this blink faster or slower , you would just turn this knob and basically make it pulse faster or slower .
# = để làm cho mạch nhày nhấp_nháy nhanh hoặc chậm hơn , bạn chỉ cần xoay núm vặn này và thay_đổi tốc_độ nháy đen một_cách đơn_giản .
# < và tôi đã làm là một người khác .
#
# > well in egypt , the rioters looted the headquarters of the egyptian secret police in april 2011 , and when they were looting the building they found lots of papers .
# = tại ai cập , khi những kẻ nổi_loạn chiếm_đóng trụ_sở của đơn_vị cảnh_sát mật ai cập vào tháng 04 năm 2011 họ đã phát_hiện ra rất nhiều tài_liệu mật .
# < và tôi đã làm .
#
# > you can go on the website , download all the design files , make them yourself .
# = bạn có_thể lên trang_web , tải về những file thiết_kế và tự làm chúng .
# < và tôi đã làm là một người khác .
#
# > they 're all important choices . '
# = tất_cả đều là sự lựa_chọn quan_trọng
# < và tôi đã làm .
#
# > i don 't know .
# = tôi không biết .
# < tôi đã làm .
#
# > and she 's hitting a 257 .
# = và đạt chỉ_số những 257 .
# < và nó là một người khác .
#
# > and it 's collected by my general practitioner as well , so he can see what 's my problem in weight , not on the very moment that i need cardiologic support or something like it , but also looking backward .
# = và bác_sỹ của tôi cũng sẽ thu được những dữ_liệu này , để ông có_thể thấy những vấn_đề liên_quan đến trọng_lượng của tôi . không chỉ ngay tại thời_điểm mà tôi cần được hỗ_trợ về tim_mạch hay điều gì khác đại_loại như_vậy , mà còn trong suốt khoảng thời_gian trước đó nữa .
# < và tôi đã làm là một người khác , tôi đã làm là một người khác , và tôi đã làm là một người khác .
#
# > now that 's sort of just a very simple chemical form of life , but when things got interesting was when these drops learned a trick about abstraction .
# = đó chỉ là một dạng hoá_học cơ_bản của sự sống , nhưng mọi thứ thú_vị hơn khi những giọt ấy học được mẹo để chiết ra .
# < và tôi đã làm là một người khác .
#
# > score them again .
# = đánh_giá lại chúng một lần nữa .
# < và nó là một người đã làm .
#
# > so in other words , i define what i wanted .
# = nói cách khác , tôi xác_định thứ tôi muốn .
# < tôi đã làm .
#
# > by being totally surprising and humorous , casey niestat got his funny idea and point seen five million times .
# = hoàn_toàn gây ngạc_nhiên và hài_hước , casey niestat đã đưa ý_tưởng vui và ý_kiến của mình cho 5 triệu lượt xem .
# < và nó là một người đã làm .
#
# > one of two things is going to happen .
# = một trong hai việc sẽ xảy ra .
# < và tôi đã làm .
#
# > my mother worked on farms , then on a car assembly line , working six days , double shifts .
# = mẹ tôi làm_việc trong trang_trại , rồi trong dây_chuyền sản_xuất ô_tô , làm_việc tuần sáu ngày , hai ca .
# < và tôi đã làm .
#
# > and finally , i believe that , despite the fact that it is so dramatic and so beautiful and so inspiring and so stimulating , we will ultimately not be judged by our technology , we won 't be judged by our design , we won 't be judged by our intellect and reason .
# = và cuối_cùng , tôi tin rằng dù sự_thật là điều này rất ly_kỳ rất tuyệt , rất hứng_thú và rất kích_thích nhưng chúng_ta cuối_cùng sẽ chẳng bị phán_xét bởi công_nghệ chúng_ta làm ra bởi thiết_kế của mình , bởi trí_tuệ và lý_tưởng
# < và tôi đã làm là một người khác , tôi đã làm là một người khác , tôi đã làm .
#
# > it 's been viewed nearly 50 million times this year .
# = video này đã có gần 50 triệu lượt xem vào năm nay .
# < và nó là một người đã làm .
#
# > and i mention that because i think identity is really important .
# = và tôi đề_cập đến điều này bởi tôi nghĩ bản_sắc thực_sự rất quan_trọng
# < tôi đã làm , tôi đã làm .
#
# > so i one day decided to pay a visit to the manager , and i asked the manager , ' is this model of offering people all this choice really working ? '
# = cho_nên , 1 ngày , tôi quyết_định lại chỗ người quản_lý , và tôi hỏi , ' cái cách mời_gọi mọi người những lựa_chọn này có thực_sự hiệu_quả ? '
# < tôi đã làm là một người khác , tôi đã làm .
#
# > i told my mother i couldn 't do it .
# = tôi bảo mẹ là tôi không_thể làm được .
# < tôi đã làm .
#
# > that 's about all it can do .
# = đó là tất_cả những gì có_thể xảy ra .
# < và tôi đã làm .
#
# > and yet , there is this disconnect .
# = và vì_thế , có sự ngăn_cách
# < và nó là một người khác .
#
# > so it 's got cute little game dynamics on it .
# = vậy là có chút động_lực cho việc này .
# < và tôi đã làm .
#
# > you can put a knob in between and now you 've made a little dimmer .
# = bạn cho một núm xoay vào giữa và giờ bạn có_thể chỉnh sáng tối cho đèn .
# < và tôi đã làm .
#
# > and so every drop was a little bit different .
# = và vì_vậy , tất_cả các giọt đều khác nhau đôi_chút .
# < và nó là một người khác .
#
# > because i believe that the key to getting the most from choice is to be choosy about choosing .
# = bởi_vì tôi tin rằng chìa_khoá để chọn cái tốt nhất từ sự lựa_chọn đó là sự kĩ_càng trong lựa_chọn
# < tôi đã làm .
#
# > this is a generation that 's grown up taking their voices pretty much for granted .
# = đây là thế_hệ dùng tiếng_nói của mình để đấu_tranh cho quyền_lợi .
# < và tôi đã làm .
#
# > well the answer is , if i drew it on a normal curve where , let 's say , this is years , this is time of some sort , and this is whatever measure of the technology that i 'm trying to graph , the graphs look sort of silly .
# = câu trả_lời là , nếu tôi vẽ nó trên một đường_cong bình_thường đây , có_thể nói , là năm , đây là một loại thời_gian , và bất_kể đây là thước_đo công_nghệ gì tôi đang cố_gắng minh_hoạ , đồ_thị đều trông rất ngớ_ngẩn .
# < tôi đã làm là một người khác , tôi đã làm là một người khác , tôi đã làm .
#
# > what am i going to look at ?
# = điều tôi muốn nói là gì ?
# < tôi đã làm .
#
# > here i have a very complicated , messy , confused idea in my head .
# = tôi có một suy_nghĩ hết_sức phức_tạp , hỗn_độn , và mơ_hồ trong tâm_trí .
# < tôi đã làm .
#
# > i was taking a shower in a hotel room in sydney the moment she died 600 miles away in melbourne .
# = tôi đang tắm trong một phòng khách_sạn ở sydney vào thời_khắc bà mất cách đó 600 dặm , ở melbourne .
# < tôi đã làm .
#
# > they haven 't given up on government .
# = họ chưa từ_bỏ
# < và tôi đã làm .
#
# > boston doesn 't just have a call center .
# = boston không chỉ có một tổng_đài .
# < và tôi đã làm .
#
# > ' you have not let it go . '
# = ' các chị không hề buông tay . '
# < và tôi đã làm là một người khác .
#
# > they 're motivated by something else -- motivated by protests , motivated by an opinion , motivated by the laughs .
# = họ được thúc_đẩy vì những mục_đích khác - - chống_đối chính_phủ , bất_đồng chính_kiến , và đôi_khi cũng chỉ để vui_đùa .
# < và tôi đã làm .
#
# > and all the while , i was amassing more and more knowledge .
# = và trong suốt quá_trình , tôi thu_thập ngày_càng nhiều kiến_thức .
# < và tôi đã làm .
#
# > i don 't remember the pirates who came many times , but were bluffed by the bravado of the men on our boat , or the engine dying and failing to start for six hours .
# = tôi không nhớ lũ cướp biến đã đến rất nhiều lần , nhưng bị lừa bỏ đi bởi sự dũng càm của những người đàn_ông trên thuyền , hay_là khi máy tàu bị chết và không khởi_động được trong suốt sáu tiếng đồng_hồ .
# < tôi đã làm .
#
# > because being an insider can so easily mean collapsing the horizons , can so easily mean accepting the presumptions of your province .
# = bời vì làm người đứng phía trong có_thể dễ bị thu_hẹp tầm nhìn , có_thể dễ_dàng chấp_nhận những định_kiến trong khu_vực của bạn .
# < và tôi đã làm là một người khác .
#
# > so i 've got now a new generation of programs that are produced by combinations of the programs that did a little bit better job .
# = tôi có hiện_nay một thế_hệ chương_trình mới được sản_xuất bởi sự kết_hợp của các chương_trình mà thực_hiện công_việc tốt hơn một_chút .
# < tôi đã làm .
#
# > it suggests how government could work better -- not more like a private company , as many people think it should .
# = nó cho thấy cách mà chính_phủ có_thể hoạt_động hiệu_quả hơn - - không giống các công_ty tư_nhân , như nhiều người nghĩ .
# < và tôi đã làm là một người khác .
#
# > but for african-americans in this country , that was an era defined by terror .
# = nhưng đối_với người mỹ gốc phi ở quốc_gia này đó là một thời_kỳ khủng_khiếp .
# < và tôi đã làm .
#
# > if you keep hitting the default button per decision , that means you 're getting overwhelmed , that means i 'm losing you .
# = nếu bạn cứ nhấn nút ' mặc_định ' cho mỗi quyết_định điều đó có_nghĩa bạn đang bị quá nhiều lựa_chọn , điều đó có_nghĩa_là bạn thua tôi rồi
# < tôi đã làm là một người khác , tôi đã làm là một người khác .
#
# > he said , ' i 'm so proud of you . '
# = ông nói : ' tôi rất tự_hào về cậu '
# < tôi đã làm là một người khác , tôi đã làm .
#
# > otherwise , when i ask you a question , and if your answer is yes , i 'd like you to clap your hands .
# = nếu không thì , khi tôi hỏi , và nếu bạn trả_lời có , xin bạn vui vòng vỗ_tay ,
# < tôi đã làm là một người khác , tôi đã làm .
#
# > so you heard and saw an obvious desire by this audience , this community , to help you on your way and to do something on this issue .
# = vậy anh đã nghe và đã thấy được mong_muốn của quý_vị khán_giả , cuả cộng_đồng ted để giúp anh trên con đường của mình và làm được điều gì đó đối_với vấn_đề này .
# < và tôi đã làm là một người khác , tôi đã làm .
