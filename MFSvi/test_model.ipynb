# %%
device = 'cuda'

# model parameter setting
batch_size = 164
max_len = 100
d_model = 256
n_layers = 2
n_heads = 8
ffn_hidden = 512
drop_prob = 0.1

# optimizer parameter setting
init_lr = 1e-3
factor = 0.6
adam_eps = 5e-9
patience = 7
warmup = 100
epoch = 500
clip = 1.0
weight_decay = 5e-4 ###
inf = float('inf')

import torch
from torch import nn, optim
from torch.optim import Adam
import torch.utils.data as data
import math
from collections import Counter
import collections
import numpy as np
import copy
import time
import spacy
from torchtext.datasets import Multi30k
from torchtext.data import Field, BucketIterator
import time

start_time = time.time()

class DataLoader:
    source: Field = None
    target: Field = None

    def __init__(self, ext, tokenize_en, tokenize_vi, init_token, eos_token):
        self.ext = ext
        self.tokenize_en = tokenize_en
        self.tokenize_vi = tokenize_vi
        self.init_token = init_token
        self.eos_token = eos_token
        print('dataset initializing start')

    def make_dataset(self):
        if self.ext == ('.vi', '.en'):
            self.source = Field(tokenize=self.tokenize_vi, init_token=self.init_token, eos_token=self.eos_token,
                                lower=True, batch_first=True)
            self.target = Field(tokenize=self.tokenize_en, init_token=self.init_token, eos_token=self.eos_token,
                                lower=True, batch_first=True)

        elif self.ext == ('.en', '.vi'):
            self.source = Field(tokenize=self.tokenize_en, init_token=self.init_token, eos_token=self.eos_token,
                                lower=True, batch_first=True)
            self.target = Field(tokenize=self.tokenize_vi, init_token=self.init_token, eos_token=self.eos_token,
                                lower=True, batch_first=True)

        train_data, valid_data, test_data = Multi30k.splits(exts=self.ext, fields=(self.source, self.target))
        return train_data, valid_data, test_data

    def build_vocab(self, train_data, min_freq):
        self.source.build_vocab(train_data, min_freq=min_freq)
        self.target.build_vocab(train_data, min_freq=min_freq)

    def make_iter(self, train, validate, test, batch_size):
        train_iterator, valid_iterator, test_iterator = BucketIterator.splits((train, validate, test),
                                                                              batch_size=batch_size)
        print('dataset initializing done')
        return train_iterator, valid_iterator, test_iterator

from pyvi import ViTokenizer
import spacy
from spacy.language import Language
from spacy.tokens import Doc

# Custom tokenizer function
def custom_tokenizer(nlp, text):
    words = ViTokenizer.tokenize(text).split()
    return Doc(nlp.vocab, words=words)

class Tokenizer:
    def __init__(self):
        self.spacy_vi = spacy.blank("en")
        self.spacy_vi.tokenizer = custom_tokenizer.__get__(self.spacy_vi)
        
        self.spacy_en = spacy.load('en_core_web_sm')

    def tokenize_vi(self, text):
        return [tok.text for tok in self.spacy_vi.tokenizer(text)]

    def tokenize_en(self, text):
        return [tok.text for tok in self.spacy_en.tokenizer(text)]


# In[4]:

tokenizer = Tokenizer()
loader = DataLoader(ext=('.en', '.vi'),
                    tokenize_en=tokenizer.tokenize_en,
                    tokenize_vi=tokenizer.tokenize_vi,
                    init_token='<sos>',
                    eos_token='<eos>')

train, valid, test = loader.make_dataset()
loader.build_vocab(train_data=train, min_freq=1)
train_iter, valid_iter, test_iter = loader.make_iter(train, valid, test,
                                                     batch_size=batch_size)

src_pad_idx = loader.source.vocab.stoi['<pad>']
trg_pad_idx = loader.target.vocab.stoi['<pad>']
trg_sos_idx = loader.target.vocab.stoi['<sos>']

enc_voc_size = len(loader.source.vocab)
dec_voc_size = len(loader.target.vocab)
# Out:
# dataset initializing start
# dataset initializing done

# %%
class ScaleDotProductAttention(nn.Module):
    def __init__(self):
        super(ScaleDotProductAttention, self).__init__()
        self.softmax = nn.Softmax(dim = -1)

    def forward(self, q, k ,v, mask = None, e = 1e-12):
        batch_size, head, length, d_tensor = k.size()
        k_t = k.transpose(2,3)
        score = (q @ k_t) / math.sqrt(d_tensor)

        if mask is not None:
            score = score.masked_fill(mask == 0, -10000)

        score = self.softmax(score)
        v = score @ v
        return v, score

class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, n_head):
        super(MultiHeadAttention, self).__init__()
        self.n_head = n_head # Number of attention heads
        self.attention = ScaleDotProductAttention()
        self.w_q = nn.Linear(d_model, d_model) # Query transformation
        self.w_k = nn.Linear(d_model, d_model) # Key
        self.w_v = nn.Linear(d_model, d_model) # Value
        self.w_concat = nn.Linear(d_model, d_model)

    def split(self, tensor):
        batch_size, length, d_model = tensor.size()
        d_tensor = d_model // self.n_head
        tensor = tensor.view(batch_size, length, self.n_head, d_tensor).transpose(1,2).to(device)
        return tensor

    def concat(self, tensor):
        batch_size, head, length, d_tensor = tensor.size()
        d_model = head * d_tensor
        tensor = tensor.transpose(1,2).contiguous().view(batch_size, length, d_model).to(device)
        return tensor

    def forward(self, q, k, v, mask = None):
        q, k, v = self.w_q(q), self.w_k(k), self.w_v(v)
        q, k, v = self.split(q), self.split(k), self.split(v)

        out, attention = self.attention(q, k, v, mask = mask)

        out = self.concat(out)
        out = self.w_concat(out)
        return out


# In[7]:


class PositionwiseFeedForward(nn.Module):
    def __init__(self, d_model, hidden, drop_prob=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.linear1 = nn.Linear(d_model, hidden)
        self.linear2 = nn.Linear(hidden, d_model)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p = drop_prob)

    def forward(self, x):
        return self.linear2(self.dropout(self.relu(self.linear1(x))))


# In[8]:


class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len):
        super(PositionalEncoding, self).__init__()

        self.encoding = torch.zeros(max_len, d_model).to(device)
        self.encoding.requires_grad = False
        pos = torch.arange(0, max_len, dtype = torch.float).unsqueeze(1).to(device)
        _2i = torch.arange(0, d_model, step = 2).float().to(device)
        self.encoding[:, 0::2] = torch.sin(pos / (10000 ** (_2i/d_model)))
        self.encoding[:, 1::2] = torch.cos(pos / (10000 ** (_2i/d_model)))

    def forward(self, x):
        batch_size, seq_len = x.size()
        return self.encoding[:seq_len, :].to(device)


# In[9]:


class LayerNorm(nn.Module):
    def __init__(self, d_model, eps=1e-12):
        super(LayerNorm, self).__init__()
        self.gamma = nn.Parameter(torch.ones(d_model))
        self.beta = nn.Parameter(torch.zeros(d_model))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        var = x.var(-1, unbiased=False, keepdim=True)
        # '-1' means last dimension.

        out = (x - mean) / torch.sqrt(var + self.eps)
        out = self.gamma * out + self.beta
        return out

class TokenEmbedding(nn.Embedding):
   def __init__(self, vocab_size, d_model):
       super(TokenEmbedding, self).__init__(vocab_size, d_model, padding_idx=1)

class TransformerEmbedding(nn.Module):
    def __init__(self, vocab_size, d_model, max_len, drop_prob):
        super(TransformerEmbedding, self).__init__()
        self.tok_emb = TokenEmbedding(vocab_size, d_model)
        self.pos_emb = PositionalEncoding(d_model, max_len)
        self.drop_out = nn.Dropout(p=drop_prob)
    
    def forward(self, x):
        tok_emb = self.tok_emb(x)
        pos_emb = self.pos_emb(x)
        return self.drop_out(tok_emb + pos_emb)


# In[10]:


class EncoderLayer(nn.Module):
    def __init__(self, d_model, ffn_hidden, n_head, drop_prob):
        super(EncoderLayer, self).__init__()
        self.attention = MultiHeadAttention(d_model, n_head)
        self.ffn = PositionwiseFeedForward(d_model, ffn_hidden, drop_prob)
        self.norm1 = LayerNorm(d_model)
        self.norm2 = LayerNorm(d_model)
        self.dropout1 = nn.Dropout(p = drop_prob)
        self.dropout2 = nn.Dropout(p = drop_prob)

    def forward(self, x, src_mask):
        _x = x
        x = self.attention(x, x, x, src_mask)
        x = self.dropout1(x)
        x = self.norm1(x + _x)

        _x = x
        x = self.ffn(x)
        x = self.dropout2(x)
        x = self.norm2(x + _x)
        return x

class Encoder(nn.Module):
    def __init__(self, enc_voc_size, max_len, d_model, ffn_hidden, n_head, n_layers, drop_prob):
        super().__init__()
        self.emb = TransformerEmbedding(d_model=d_model,
                                        max_len=max_len,
                                        vocab_size=enc_voc_size,
                                        drop_prob=drop_prob)

        self.layers = nn.ModuleList([EncoderLayer(d_model=d_model,
                                                  ffn_hidden=ffn_hidden,
                                                  n_head=n_head,
                                                  drop_prob=drop_prob)
                                     for _ in range(n_layers)])

    def forward(self, x, src_mask):
        x = self.emb(x)

        for layer in self.layers:
            x = layer(x, src_mask)

        return x


# In[11]:


class DecoderLayer(nn.Module):
    def __init__(self, d_model, ffn_hidden, n_head, drop_prob):
        super(DecoderLayer, self).__init__()
        self.self_attention = MultiHeadAttention(d_model, n_head)
        self.enc_dec_attention = MultiHeadAttention(d_model, n_head)
        self.ffn = PositionwiseFeedForward(d_model, ffn_hidden, drop_prob)
        self.norm1 = LayerNorm(d_model)
        self.norm2 = LayerNorm(d_model)
        self.norm3 = LayerNorm(d_model)
        self.dropout1 = nn.Dropout(p = drop_prob)
        self.dropout2 = nn.Dropout(p = drop_prob)
        self.dropout3 = nn.Dropout(p = drop_prob)

    def forward(self, dec, enc, trg_mask, src_mask):
        _x = dec
        x = self.self_attention(dec, dec, dec, trg_mask)
        x = self.dropout1(x)
        x = self.norm1(x + _x)

        if enc is not None:
            _x = x
            x = self.enc_dec_attention(q=x, k=enc, v=enc, mask=src_mask)

            x = self.dropout2(x)
            x = self.norm2(x + _x)

        _x = x
        x = self.ffn(x)
        x = self.dropout3(x)
        x = self.norm3(x + _x)
        return x

class Decoder(nn.Module):
    def __init__(self, dec_voc_size, max_len, d_model, ffn_hidden, n_head, n_layers, drop_prob):
        super().__init__()
        self.emb = TransformerEmbedding(d_model=d_model,
                                        drop_prob=drop_prob,
                                        max_len=max_len,
                                        vocab_size=dec_voc_size)

        self.layers = nn.ModuleList([DecoderLayer(d_model=d_model,
                                                  ffn_hidden=ffn_hidden,
                                                  n_head=n_head,
                                                  drop_prob=drop_prob)
                                     for _ in range(n_layers)])

        self.linear = nn.Linear(d_model, dec_voc_size)

    def forward(self, trg, enc_src, trg_mask, src_mask):
        trg = self.emb(trg)

        for layer in self.layers:
            trg = layer(trg, enc_src, trg_mask, src_mask)
        output = self.linear(trg)
        return output


# In[12]:


class Transformer(nn.Module):

    def __init__(self, src_pad_idx, trg_pad_idx, trg_sos_idx, enc_voc_size, dec_voc_size, d_model, n_head, max_len,
                 ffn_hidden, n_layers, drop_prob):
        super().__init__()
        self.src_pad_idx = src_pad_idx
        self.trg_pad_idx = trg_pad_idx
        self.trg_sos_idx = trg_sos_idx
        self.encoder = Encoder(d_model=d_model,
                               n_head=n_head,
                               max_len=max_len,
                               ffn_hidden=ffn_hidden,
                               enc_voc_size=enc_voc_size,
                               drop_prob=drop_prob,
                               n_layers=n_layers)

        self.decoder = Decoder(d_model=d_model,
                               n_head=n_head,
                               max_len=max_len,
                               ffn_hidden=ffn_hidden,
                               dec_voc_size=dec_voc_size,
                               drop_prob=drop_prob,
                               n_layers=n_layers)

    def forward(self, src, trg):
        src_mask = self.make_src_mask(src)
        trg_mask = self.make_trg_mask(trg)
        enc_src = self.encoder(src, src_mask)
        output = self.decoder(trg, enc_src, trg_mask, src_mask)
        return output

    def make_src_mask(self, src):
        src_mask = (src != self.src_pad_idx).unsqueeze(1).unsqueeze(2)
        return src_mask.to(device)

    def make_trg_mask(self, trg):
        trg_pad_mask = (trg != self.trg_pad_idx).unsqueeze(1).unsqueeze(3)
        trg_len = trg.shape[1]
        trg_sub_mask = torch.tril(torch.ones(trg_len, trg_len)).type(torch.ByteTensor).to(device)
        trg_mask = trg_pad_mask & trg_sub_mask
        return trg_mask.to(device)


# In[13]:


def get_bleu(pred_seq, label_seq, k = 4):
    """Compute the BLEU."""
    pred_tokens, label_tokens = pred_seq.split(' '), label_seq.split(' ')
    len_pred, len_label = len(pred_tokens), len(label_tokens)
    score = math.exp(min(0, 1 - len_label / len_pred))


    for n in range(1, min(k, len_pred) + 1):
        num_matches, label_subs = 0, collections.defaultdict(int)
        for i in range(len_label - n + 1):
            label_subs[' '.join(label_tokens[i: i + n])] += 1

        for i in range(len_pred - n + 1):
            if label_subs[' '.join(pred_tokens[i: i + n])] > 0:
                num_matches += 1
                label_subs[' '.join(pred_tokens[i: i + n])] -= 1
        
        #print(num_matches)

        score *= math.pow(num_matches / (len_pred - n + 1), math.pow(0.5, n))
    return score


def idx_to_word(x, vocab):
    words = []
    for i in x:
        word = vocab.itos[i]
        if '<' not in word:
            words.append(word)
    words = " ".join(words)
    return words


# In[14]:


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


def initialize_weights(m):
    if hasattr(m, 'weight') and m.weight.dim() > 1:
        nn.init.kaiming_uniform(m.weight.data)



loaded_model = Transformer(src_pad_idx=src_pad_idx,
                    trg_pad_idx=trg_pad_idx,
                    trg_sos_idx=trg_sos_idx,
                    d_model=d_model,
                    enc_voc_size=enc_voc_size,
                    dec_voc_size=dec_voc_size,
                    max_len=max_len,
                    ffn_hidden=ffn_hidden,
                    n_head=n_heads,
                    n_layers=n_layers,
                    drop_prob=drop_prob).to(device)
print(f'The model has {count_parameters(loaded_model):,} trainable parameters')


model_path = '/home/k64t/person-reid/MFSvi/models/best_bleu_retrain.pth'
loaded_model.load_state_dict(torch.load(f = model_path))
# Out:
# The model has 30,542,231 trainable parameters
# <All keys matched successfully>

# %%
def evaluate(model, iterator, criterion):
    model.eval()
    epoch_loss = 0
    batch_bleu = []
    with torch.no_grad():
        for i, batch in enumerate(iterator):
            src = batch.src
            trg = batch.trg

            src = src.to(device)
            trg = trg.to(device)

            output = model(src, trg[:, :-1])
            output_reshape = output.contiguous().view(-1, output.shape[-1])
            trg = trg[:, 1:].contiguous().view(-1)

            loss = criterion(output_reshape, trg)
            epoch_loss += loss.item()

            total_bleu = []
            for j in range(batch_size):
                try:
                    trg_words = idx_to_word(batch.trg[j], loader.target.vocab)
                    output_words = output[j].max(dim=1)[1]
                    output_words = idx_to_word(output_words, loader.target.vocab)

                    sentences = idx_to_word(batch.src[j], loader.source.vocab)

                    print("Sentence : " + sentences)
                    print("Original : " + trg_words)
                    print("Translator : " + output_words)
                    
                    #print(get_bleu(output_words, trg_words))
                    print('-' * 30)

                    bleu = get_bleu(output_words, trg_words)

                    total_bleu.append(bleu)
                except:
                    pass

            total_bleu = sum(total_bleu) / len(total_bleu)
            batch_bleu.append(total_bleu)

            #src = src.detach()
            #trg = trg.detach()
            torch.cuda.empty_cache()

    batch_bleu = sum(batch_bleu) / len(batch_bleu)
    return epoch_loss / len(iterator), batch_bleu

criterion = nn.CrossEntropyLoss(ignore_index=src_pad_idx)
test_loss, bleu = evaluate(loaded_model, test_iter, criterion)
print(test_loss, bleu)
# Out:
# Sentence : as you can imagine , the town had been devastated .
# Original : có_thể_hình_dung , thị_trấn đã bị tàn_phá .
# Translator : như rằng thành_phố đã bị tàn_phá . . . . . .
# ------------------------------
# Sentence : who in the room has a mobile phone with you ?
# Original : những_ai trong khán_phòng có điện_thoại_di_động ?
# Translator : ai trong phòng có một với ? ? ? ? ?
# ------------------------------
# Sentence : i wasn ' t a citizen of that country .
# Original : tôi không phải công_dân nước đó .
# Translator : tôi không phải là của đó . . . .
# ------------------------------
# Sentence : see , i have a legacy in south central .
# Original : tôi có di_sản ở vùng nam_trung .
# Translator : tôi có một ở nam miền . . . . . .
# ------------------------------
# Sentence : why in the hell would they not okay this ?
# Original : làm_sao họ có_thể không đồng_tình chứ ?
# Translator : tại_sao trong không không được gì ? ? ?
# ------------------------------
# Sentence : i ' m always the one taking the picture .
# Original : tôi luôn là người chụp ảnh .
# Translator : tôi luôn lấy một luôn hình . . .
# ------------------------------
# Sentence : tell us why your science is relevant to us .
# Original : tại_sao khoa_học liên_quan đến chúng_tôi .
# Translator : nói khoa_học lại đến chúng_ta đến . . . .
# ------------------------------
# Sentence : thirty - five thousand eight hundred thirty lines of information .
# Original : dãy các thông_tin .
# Translator : 30 5 năm trăm 30 8
# ------------------------------
# Sentence : i want to shine a light on slavery .
# Original : tôi muốn đưa nô_lệ ra ánh_sáng .
# Translator : tôi muốn chiếu ra cho cho . . . . .
# ------------------------------
# Sentence : i ' m still breaking the silence today .
# Original : tôi đang đập_tan sự im_lặng hôm_nay .
# Translator : tôi vẫn vẫn sự im_lặng ngày . . . . .
# ------------------------------
# Sentence : he wasn ' t alone when he started .
# Original : ông ấy không bắt_đầu một_mình .
# Translator : ông ấy không chỉ khi khi .
# ------------------------------
# Sentence : mercury is used in the extraction process .
# Original : thuỷ_ngân được dùng trong quá_trình chiết_xuất .
# Translator : phthalate đã sử_dụng trong quá_trình khai_thác .
# ------------------------------
# Sentence : i want to introduce you to kofi .
# Original : tôi muốn giới_thiệu kofi với bạn .
# Translator : tôi muốn giới_thiệu với sự các . . . .
# ------------------------------
# Sentence : they have nothing to compare it to .
# Original : họ không có gì để so_sánh .
# Translator : họ không có gì để so_sánh nó .
# ------------------------------
# Sentence : we don ' t work from offices .
# Original : chúng_tôi không làm_việc từ những văn_phòng .
# Translator : chúng_tôi không làm_việc từ văn_phòng văn_phòng . . .
# ------------------------------
# Sentence : the first principle of aid is respect .
# Original : nguyên_tắc đầu_tiên về viện_trợ là tôn_trọng .
# Translator : nguyên_tắc đầu_tiên của sự là tôn_trọng . . . . .
# ------------------------------
# Sentence : thank you so much . thank you .
# Original : cảm_ơn cháu rất nhiều . cảm_ơn .
# Translator : cảm_ơn rất rất nhiều . cảm_ơn . . . . .
# ------------------------------
# Sentence : and i said , ' yes . '
# Original : tôi trả_lời , ' vâng ' .
# Translator : và nói , ' vâng . '
# ------------------------------
# Sentence : it 's really become sacred to us .
# Original : nó trở_nên thật thiêng_liêng với chúng_tôi .
# Translator : nó thực_sự thiêng_liêng thiêng_liêng . chúng_ta . . .
# ------------------------------
# Sentence : and he was very , very sorry .
# Original : và anh ta đã vô_cùng hối_lỗi .
# Translator : và ông ấy rất rất xin_lỗi .
# ------------------------------
# Sentence : so a microwave is a similar system .
# Original : cũng có hệ_thống hoạt_động tương_tự .
# Translator : vậy là giống một tương_tự tương_tự .
# ------------------------------
# Sentence : sometimes you can create potholes with that .
# Original : đôi_khi chúng tạo nên các ổ_gà .
# Translator : đôi_khi bạn có_thể ra sự sự với . . . . .
# ------------------------------
# Sentence : but most people don ' t agree .
# Original : nhưng hầu_hết mọi người không đồng_ý .
# Translator : nhưng hầu_hết mọi người không đồng_ý . . . . .
# ------------------------------
# Sentence : this young child is eight years old .
# Original : đứa trẻ này 8 tuổi .
# Translator : đứa trẻ này là tuổi . . . . .
# ------------------------------
# Sentence : the internal combustion engine is not sustainable .
# Original : động_cơ đốt trong không bền_vững .
# Translator : động_cơ đốt trong cơ_thể bền_vững . . . .
# ------------------------------
# Sentence : so what is the problem with vultures ?
# Original : kền_kền đang bị sao ?
# Translator : vậy với có gì ảnh_hưởng ? ?
# ------------------------------
# Sentence : he has a selective one , though .
# Original : nhưng cũng là có chọn_lọc .
# Translator : ông ông có một một một . . . .
# ------------------------------
# Sentence : now don ' t get me wrong .
# Original : đừng hiểu lầm tôi .
# Translator : bây_giờ hiểu sai tôi . .
# ------------------------------
# Sentence : see , i ' m an artist .
# Original : tôi là một nghệ_sĩ .
# Translator : tôi thấy một nghệ_sĩ . .
# ------------------------------
# Sentence : vultures also have tremendous historical significance .
# Original : kền_kền cũng có một lịch_sử hoành_tráng về tầm quan_trọng của chúng .
# Translator : chim cũng có những ý_nghĩa to_lớn . lịch_sử quan_trọng . lịch_sử .
# ------------------------------
# Sentence : not everybody gets to do that .
# Original : không phải ai cũng có cơ_hội để làm điều này .
# Translator : không phải ai cũng làm làm . làm điều đó .
# ------------------------------
# Sentence : talk about what you heard here .
# Original : hãy kể về những gì bạn được nghe ở đây .
# Translator : nói nói về những gì bạn nghe nghe ở đây . .
# ------------------------------
# Sentence : thinking about death clarifies your life .
# Original : suy_nghĩ về cái chết làm cuộc_sống của bạn rõ_ràng .
# Translator : nghĩ về việc chết đã thay_đổi của bạn . . .
# ------------------------------
# Sentence : who sends whom a text message ?
# Original : ai đã gửi cho ai những tin nhắn di_động ?
# Translator : ai đã gửi cho họ một thông_điệp nhắn ? ? ? ?
# ------------------------------
# Sentence : several times we can repeat that .
# Original : chúng_tôi có_thể làm đi làm lại nhiều lần như_vậy .
# Translator : vài có_thể lặp được . thế điều lần . .
# ------------------------------
# Sentence : my interpreter told me their stories .
# Original : người phiên_dịch của tôi kể chuyện của họ .
# Translator : tôi dịch tôi tôi kể cho của mình . .
# ------------------------------
# Sentence : just go and read her book .
# Original : hãy tìm đọc cuốn sách của bà ấy .
# Translator : chỉ đọc đọc sách sách của cô . . .
# ------------------------------
# Sentence : one of them was this grandmother .
# Original : một trong số đó là người bà này .
# Translator : một trong số họ là bà bà này . . .
# ------------------------------
# Sentence : i want to make them public .
# Original : tôi muốn nó được biết đến bởi công_chúng .
# Translator : tôi muốn làm làm làm . công_chúng công_chúng .
# ------------------------------
# Sentence : and why are these there ?
# Original : nhưng tại_sao những thông_tin đó lại ở đây ?
# Translator : và tại_sao những người này lại có đây ? ?
# ------------------------------
# Sentence : they 're our natural garbage collectors .
# Original : chúng thật_sự là những gã gom rác tự_nhiên .
# Translator : chúng là là những nhà khổng_lồ lại . . . . .
# ------------------------------
# Sentence : he needed them to feel protected .
# Original : anh ta cần chúng để cảm_thấy được bảo_vệ .
# Translator : anh ta cần họ để cảm_thấy được bảo_vệ . . . .
# ------------------------------
# Sentence : don ' t they sound incredible ?
# Original : những chuyện này nghe thật tuyệt_vời phải không ?
# Translator : họ âm_thanh này không có tuyệt_vời ? không ?
# ------------------------------
# Sentence : today i have just one request .
# Original : hôm_nay tôi chỉ có một yêu_cầu mà thôi .
# Translator : hôm_nay tôi có có một yêu_cầu . thôi .
# ------------------------------
# Sentence : she 's not north korean . '
# Original : nó không phải là người bắc triều_tiên . '
# Translator : cô không phải là bắc hàn_quốc triều_tiên . ' '
# ------------------------------
# Sentence : this person has never been born .
# Original : nhân_vật này chưa bao_giờ được sinh ra .
# Translator : người này chưa bao_giờ được sinh ra . . .
# ------------------------------
# Sentence : they were already drowning in manure .
# Original : họ sẽ bị trong phân ngựa .
# Translator : họ đã chết chết trong sự . . . . .
# ------------------------------
# Sentence : so planning has this blind spot .
# Original : vậy nên hoạch_định có một điểm_mù này .
# Translator : vì_vậy nên kế_hoạch nên cái nơi . . . .
# ------------------------------
# Sentence : let me tell you a secret .
# Original : để tôi nói bạn biết một bí_mật .
# Translator : hãy tôi nói với nói bí_mật bí_mật . . . .
# ------------------------------
# Sentence : you can give somebody an idea .
# Original : bạn có_thể cho ai đó một ý_tưởng .
# Translator : bạn có_thể đưa ai đó một ý_tưởng . . .
# ------------------------------
# Sentence : do they know where we live ?
# Original : họ có biết chỗ chúng_tôi ở không ?
# Translator : họ biết biết nơi chúng_ta sống đâu ? ?
# ------------------------------
# Sentence : they are bird - blending machines .
# Original : chúng là máy nghiền những chú chim .
# Translator : chúng là những kết_hợp chim cỗ chim . . .
# ------------------------------
# Sentence : and i 'll tell you why .
# Original : tôi sẽ nói cho bạn biết tại_sao .
# Translator : và sẽ nói với các tại_sao tại_sao .
# ------------------------------
# Sentence : he told me two things .
# Original : anh ta kể với tôi về hai thứ .
# Translator : ông ta nói với tôi hai hai điều . .
# ------------------------------
# Sentence : so we started photos .
# Original : chúng_tôi bắt_đầu chỉnh_sửa những tấm ảnh này .
# Translator : vì_vậy bắt_đầu chụp các bức ảnh . . .
# ------------------------------
# Sentence : abuse thrives only in silence .
# Original : sự ngược_đãi chỉ đáng sợ trong im_lặng .
# Translator : lạm_dụng lạm_dụng chỉ có kinh_ngạc trong sự . .
# ------------------------------
# Sentence : these girls were so lucky .
# Original : những cô gái này đã rất may_mắn .
# Translator : những cô gái này rất may_mắn may_mắn . . .
# ------------------------------
# Sentence : and i was very proud .
# Original : tôi đã rất tự_hào về đất_nước tôi .
# Translator : và rất rất tự_hào . . này . .
# ------------------------------
# Sentence : she also had duplicates .
# Original : cô cũng đã có bản_sao của bức ảnh .
# Translator : cô ấy có có một . nó ảnh . . .
# ------------------------------
# Sentence : plus you get strawberries .
# Original : , bạn còn thu được dâu nữa .
# Translator : bạn bạn bạn có có được cây . .
# ------------------------------
# Sentence : they are hardly monogamous .
# Original : họ hầu_như một vợ - một chồng .
# Translator : họ không không . người . .
# ------------------------------
# Sentence : we victims need everyone .
# Original : chúng_ta những nạn_nhân cần đến tất_cả mọi người .
# Translator : chúng_ta cần nạn_nhân cần mọi mọi mọi người . . .
# ------------------------------
# Sentence : we have zero infrastructure .
# Original : chúng_tôi không có bất_cứ cơ_sở hạ_tầng nào .
# Translator : chúng_ta có có cơ_sở cơ_sở hạ_tầng . . .
# ------------------------------
# Sentence : wrong . they were all enslaved .
# Original : sai . họ đều bị nô_lệ .
# Translator : sai . tất_cả đều là nô_lệ . . . .
# ------------------------------
# Sentence : but they mean two different things .
# Original : những chúng mang hai nghĩa khác_biệt .
# Translator : nhưng thứ có_nghĩa_là lại thứ khác . . . .
# ------------------------------
# Sentence : the book was published in 2009 .
# Original : cuốn sách được phát_hành năm 2009 .
# Translator : cuốn sách được xuất_bản vào 2009 .
# ------------------------------
# Sentence : but you have to maintain it .
# Original : nhưng bạn phải trông giữ nó .
# Translator : nhưng bạn phải giữ nó nó . .
# ------------------------------
# Sentence : you can see all of this .
# Original : bạn có_thể thấy tất_cả điều đó .
# Translator : bạn có_thể thấy tất_cả những này . .
# ------------------------------
# Sentence : it 's about all of us .
# Original : nó là thông_tin về tất_cả chúng_ta .
# Translator : đó là tất_cả về tất_cả chúng_ta .
# ------------------------------
# Sentence : and i will talk about this .
# Original : tôi sẽ nói về điều đó .
# Translator : và sẽ nói về điều này .
# ------------------------------
# Sentence : we 're working with local communities .
# Original : chúng_tôi đang hợp_tác với những cộng_đồng địa_phương
# Translator : chúng_ta đang làm_việc với cộng_đồng cộng_đồng địa_phương . . . . . .
# ------------------------------
# Sentence : they are far from being extinct .
# Original : họ còn lâu mới bị tuyệt_chủng .
# Translator : chúng đang xa từ bị tuyệt_chủng . . . .
# ------------------------------
# Sentence : it may even be your story .
# Original : đây có_thể là câu_chuyện của bạn .
# Translator : thậm_chí thậm_chí là câu_chuyện của bạn . . .
# ------------------------------
# Sentence : he has the most memory .
# Original : em có một trí_nhớ cực hoàn_hảo .
# Translator : ông có những ký_ức nhất lớn nhất . . . . .
# ------------------------------
# Sentence : in the cold , windy night .
# Original : trong đêm_tối lạnh_lẽo gió sương .
# Translator : trong đêm , , . . . . . .
# ------------------------------
# Sentence : it was more like a restaurant .
# Original : nó giống 1 nhà_hàng hơn .
# Translator : nó giống như nhà_hàng . . . .
# ------------------------------
# Sentence : we 're pale , gray creatures .
# Original : chúng_tôi là những sinh_vật xanh_xao ,
# Translator : chúng_ta là những sinh_vật màu . . . . . .
# ------------------------------
# Sentence : dearborn , michigan . henry ford .
# Original : dearborn , michigan . henry_ford .
# Translator : michigan , michigan . henry . . . .
# ------------------------------
# Sentence : the most important thing is passion .
# Original : cái quan_trọng nhất là khát_vọng .
# Translator : điều quan_trọng nhất là đam_mê . . . .
# ------------------------------
# Sentence : we see all the same symptoms .
# Original : chúng_ta thấy đều cùng triệu_chứng .
# Translator : chúng_ta thấy tất_cả giống một .
# ------------------------------
# Sentence : it will look something like this .
# Original : giống như thế này đây .
# Translator : nó như thế này . . .
# ------------------------------
# Sentence : so why did i do that ?
# Original : tại_sao tôi lại làm như_vậy ?
# Translator : vậy tôi lại làm điều ?
# ------------------------------
# Sentence : that 's a little bit scary .
# Original : tôi đã có một_chút sợ_hãi .
# Translator : đó hơi rất một_chút đáng . . . .
# ------------------------------
# Sentence : these are lines of information .
# Original : có khoảng dãy thông_tin .
# Translator : đây những thời_gian là nhà . .
# ------------------------------
# Sentence : but i will do a trial .
# Original : nhưng để tôi thử xem .
# Translator : nhưng tôi tôi sẽ thử . .
# ------------------------------
# Sentence : and here i am today .
# Original : và tôi ở đây ngày hôm_nay .
# Translator : và đây ở đây hôm_nay hôm_nay .
# ------------------------------
# Sentence : so i had an idea .
# Original : vì_thế tôi đã có một ý_tưởng .
# Translator : tôi tôi có có một ý_tưởng . .
# ------------------------------
# Sentence : that 's 20 central parks .
# Original : tương_đương với 20 lần công_viên trung_tâm ,
# Translator : đó với 20 công_viên công_viên trung_ương . . .
# ------------------------------
# Sentence : no expensive staff time required .
# Original : không tốn thời_giờ vàng_bạc của nhân_viên .
# Translator : không có thời_gian tốn , mình . .
# ------------------------------
# Sentence : that 's the real .
# Original : đó mới là cái thật_sự .
# Translator : đó là là sự mà . . . . .
# ------------------------------
# Sentence : what is it , then ?
# Original : vậy cuối_cùng nó đã giúp_ích gì ?
# Translator : nó thì thì là là gì ?
# ------------------------------
# Sentence : we did not prioritize right .
# Original : chúng_tôi đã không ưu_tiên quyền công_dân .
# Translator : chúng_tôi không không ưu_tiên đúng . .
# ------------------------------
# Sentence : so i broke the silence .
# Original : vì_vậy tôi phát vỡ sự yên_lặng .
# Translator : vì_vậy tôi đã ra im_lặng im_lặng . . .
# ------------------------------
# Sentence : ha . he 's ready .
# Original : à . anh ta đang sẵn_sàng .
# Translator : ha . ông ta đã sẵn_sàng . .
# ------------------------------
# Sentence : government ? forget about it !
# Original : chính_phủ ư ? quên đi !
# Translator : chính_phủ ? ? hãy nó về
# ------------------------------
# Sentence : so i set up everything .
# Original : và tôi lắp_đặt mọi thứ .
# Translator : vì_vậy tôi đã mọi thứ .
# ------------------------------
# Sentence : this is south los angeles .
# Original : đây là vùng nam los_angeles .
# Translator : đây là los_angeles nam los_angeles . . . .
# ------------------------------
# Sentence : i live in south central .
# Original : tôi sống ở vùng trung_nam .
# Translator : tôi sống ở nam nam . . .
# ------------------------------
# Sentence : and here 's me today .
# Original : và đây là tôi bây_giờ .
# Translator : và đây là tôi hôm_nay . .
# ------------------------------
# Sentence : actually , for 10 years .
# Original : thật_ra , trong 10 năm .
# Translator : thực_ra , trong 10 năm . .
# ------------------------------
# Sentence : knows what love is .
# Original : biết tình_yêu là gì .
# Translator : sự biết biết là gì .
# ------------------------------
# Sentence : kofi is the embodiment of possibility .
# Original : kofi là hiện_thân của khả_năng
# Translator : sự là biểu_tượng của sự . . .
# ------------------------------
# Sentence : it was very time - consuming .
# Original : nó rất tốn thời_gian .
# Translator : nó rất thời_gian thời_gian . .
# ------------------------------
# Sentence : and everyone was doing the same .
# Original : tất_cả đều làm vậy .
# Translator : và mọi đang điều . .
# ------------------------------
# Sentence : it 's much better than that .
# Original : hơn mức đó nhiều chứ
# Translator : nó thế tốt tốt hơn . hơn . .
# ------------------------------
# Sentence : no , it didn ' t .
# Original : không , không hề .
# Translator : không , không phải có .
# ------------------------------
# Sentence : this is a family portrait .
# Original : đây là chân_dung gia_đình .
# Translator : đây là một gia_đình . . .
# ------------------------------
# Sentence : there were no back doors .
# Original : không có cửa hậu .
# Translator : không có cánh nào . .
# ------------------------------
# Sentence : this was the very first .
# Original : đây là tấm đầu_tiên .
# Translator : đây là điều hình . .
# ------------------------------
# Sentence : but lions are very clever .
# Original : nhưng sư_tử rất thông_minh .
# Translator : nhưng sư_tử rất thông_minh . .
# ------------------------------
# Sentence : so they kill the lions .
# Original : vì_thế họ giết sư_tử .
# Translator : vì_vậy họ giết con . . .
# ------------------------------
# Sentence : that 's the whole idea .
# Original : toàn_bộ ý_tưởng là thế_mà .
# Translator : đó ý_tưởng . . . .
# ------------------------------
# Sentence : my family believes in me .
# Original : gia_đình tôi tin_tưởng tôi .
# Translator : gia_đình tôi tin vào . . .
# ------------------------------
# Sentence : it doesn ' t exist .
# Original : điều đó không tồn_tại
# Translator : nó đó không tồn_tại . .
# ------------------------------
# Sentence : and then somebody complained .
# Original : rồi sau đó có người than_phiền .
# Translator : và ai đó ai ai phàn_nàn . . . .
# ------------------------------
# Sentence : it could take months .
# Original : có_thể mất đến hàng tháng .
# Translator : nó lấy hàng tháng tháng . .
# ------------------------------
# Sentence : they kill our livestock .
# Original : chúng giết gia_súc của chúng_tôi .
# Translator : họ giết người . chúng_ta .
# ------------------------------
# Sentence : were we being followed ?
# Original : chúng_tôi có bị theo_dõi không ?
# Translator : chúng_ta đã được theo ? ?
# ------------------------------
# Sentence : so what happened ?
# Original : vậy điều gì đã xảy ra ?
# Translator : vậy điều gì đã xảy ra ? ?
# ------------------------------
# Sentence : but many die .
# Original : nhưng rất nhiều người đã chết .
# Translator : nhưng rất nhiều người chết chết . .
# ------------------------------
# Sentence : it 's everywhere .
# Original : nó xảy ra mọi nơi .
# Translator : nó ở ra ở nơi . .
# ------------------------------
# Sentence : we take photos constantly .
# Original : chúng_tôi chụp ảnh liên_tục .
# Translator : chúng_tôi lấy ảnh liên_tục . .
# ------------------------------
# Sentence : and i was distraught .
# Original : tôi đã rất .
# Translator : và đã bị thất_vọng . .
# ------------------------------
# Sentence : peace . thank you .
# Original : chào . xin cảm_ơn .
# Translator : hoà_bình . cảm_ơn cảm_ơn . .
# ------------------------------
# Sentence : and i was scared .
# Original : tôi đã rất sợ .
# Translator : và sợ rất sợ . .
# ------------------------------
# Sentence : today i am 22 .
# Original : hôm_nay tôi 22 tuổi .
# Translator : hôm_nay tôi là tuổi . .
# ------------------------------
# Sentence : the answer is easy .
# Original : câu trả_lời rất dễ .
# Translator : câu trả_lời là dễ_dàng . .
# ------------------------------
# Sentence : i was so shocked .
# Original : tôi đã bị sốc .
# Translator : tôi đã rất sốc . .
# ------------------------------
# Sentence : thank you very much .
# Original : cảm_ơn rất nhiều .
# Translator : cảm_ơn rất nhiều . .
# ------------------------------
# Sentence : many of them drown .
# Original : nhiều em chết_đuối .
# Translator : nhiều người đã . . .
# ------------------------------
# Sentence : we are the soil .
# Original : chúng_ta là đất .
# Translator : chúng_ta là đất . .
# ------------------------------
# Sentence : thank you very much .
# Original : cám_ơn rất nhiều .
# Translator : cảm_ơn rất nhiều . .
# ------------------------------
# Sentence : you can be extraordinary .
# Original : bạn có_thể phi_thường .
# Translator : bạn có_thể là . .
# ------------------------------
# Sentence : he screamed a lot .
# Original : em la_hét nhiều .
# Translator : anh ấy . . .
# ------------------------------
# Sentence : i lost all hope .
# Original : tôi hoàn_toàn tuyệt_vọng .
# Translator : tôi mất mất . .
# ------------------------------
# Sentence : we activate communities .
# Original : chúng_tôi kích_hoạt những cộng_đồng .
# Translator : chúng_tôi đã cộng_đồng cộng_đồng . .
# ------------------------------
# Sentence : thanks , tom .
# Original : cảm_ơn nhiều , tom .
# Translator : cảm_ơn , người tom . .
# ------------------------------
# Sentence : that was awkward .
# Original : nó thật là kì_cục .
# Translator : đó thật là khó . .
# ------------------------------
# Sentence : hold it up .
# Original : hãy giơ nó lên .
# Translator : hãy giữ lên lên . .
# ------------------------------
# Sentence : a real school .
# Original : một ngôi trường thật_sự .
# Translator : một trường trường thực . .
# ------------------------------
# Sentence : there she is .
# Original : bà ấy đây .
# Translator : cô ấy ở . .
# ------------------------------
# Sentence : guess what ?
# Original : nghĩ thử xem nhé ?
# Translator : đoán gì xem gì ? ?
# ------------------------------
# Sentence : raw data .
# Original : những thông_tin sơ_cấp .
# Translator : dữ_liệu dữ_liệu thô . .
# ------------------------------
# Sentence : thank you .
# Original : cảm_ơn các bạn .
# Translator : cảm_ơn . bạn . .
# ------------------------------
# Sentence : thank you .
# Original : cảm_ơn các bạn .
# Translator : cảm_ơn . bạn . .
# ------------------------------
# Sentence : thank you .
# Original : cảm_ơn các bạn .
# Translator : cảm_ơn . bạn . .
# ------------------------------
# Sentence : thank you .
# Original : cám_ơn các bạn .
# Translator : cảm_ơn . bạn . .
# ------------------------------
# Sentence : all right .
# Original : xong rồi .
# Translator : được rồi . .
# ------------------------------
# Sentence : thank you .
# Original : cảm_ơn quý_vị .
# Translator : cảm_ơn . . .
# ------------------------------
# Sentence : not exactly .
# Original : không đúng .
# Translator : không chính_xác . .
# ------------------------------
# Sentence : thank you .
# Original : cảm_ơn bạn .
# Translator : cảm_ơn . . .
# ------------------------------
# Sentence : thank you .
# Original : cám_ơn .
# Translator : cảm_ơn . .
# ------------------------------
# Sentence : thank you .
# Original : cảm_ơn .
# Translator : cảm_ơn . .
# ------------------------------
# Sentence : thank you .
# Original : cảm_ơn .
# Translator : cảm_ơn . .
# ------------------------------
# Sentence : thank you .
# Original : vỗ_tay cám_ơn
# Translator : cảm_ơn cảm_ơn . .
# ------------------------------
# Sentence : thank you .
# Original : cảm_ơn .
# Translator : cảm_ơn . .
# ------------------------------
# Sentence : thank you .
# Original : cảm_ơn .
# Translator : cảm_ơn . .
# ------------------------------
# Sentence : thank you .
# Original : cám_ơn .
# Translator : cảm_ơn . .
# ------------------------------
# Sentence : thank you .
# Original : xin cám_ơn
# Translator : cảm_ơn cảm_ơn . .
# ------------------------------
# Sentence : absolutely .
# Original : chính_xác .
# Translator : hoàn_toàn . .
# ------------------------------
# Sentence : extraordinary .
# Original : phi_thường .
# Translator : thật . .
# ------------------------------
# Sentence : thank you .
# Original : cảm_ơn
# Translator : cảm_ơn . .
# ------------------------------
# Sentence : thank you .
# Original : cảm_ơn
# Translator : cảm_ơn . .
# ------------------------------
# Sentence : thanks .
# Original : cảm_ơn
# Translator : cảm_ơn . .
# ------------------------------
# Sentence : and , my favorite is , vultures are better looking .
# Original : và , điều mà tôi thích nhất_là , những con kền_kền trông được hơn nhiều
# Translator : và , tôi yêu tôi thích là , là con chim đang tốt tốt . hơn
# ------------------------------
# Sentence : recast survivors as wonderful , people with full futures .
# Original : viết lại cuộc_đời họ như nhưng người hạnh_phúc , đáng yêu với tương_lai rộng_mở .
# Translator : đã lại những của như những những dân nhất những kinh_ngạc thích mọi đầy_đủ .
# ------------------------------
# Sentence : he kept one in the glove compartment of our car .
# Original : anh ta giữ một cây trong ngăn chứa đồ của chiếc xe của chúng_tôi .
# Translator : anh ta giữ một trong trong chiếc đôi xe xe chúng_tôi xe của chúng_tôi .
# ------------------------------
# Sentence : he did this especially at the beginning by me .
# Original : anh ta đã làm điều đặt biệt này lúc ban_đầu bằng cách tôn_sùng tôi .
# Translator : ông ấy đã làm điều này ở này vào bắt_đầu bởi cách tôi tôi .
# ------------------------------
# Sentence : it was 7 a.m. i still had on my nightgown .
# Original : đó là lúc 7 giờ sáng khi tôi còn đang mặc áo ngủ .
# Translator : nó là 7 7 giờ sáng tôi tôi vẫn có ở chiếc của . .
# ------------------------------
# Sentence : i find that americans see the fragility in changes .
# Original : tôi thấy rằng người mỹ thấy sự yếu_ớt , dễ vỡ trong những thay_đổi .
# Translator : tôi tìm rằng người mỹ thấy sự thay_đổi trong thay_đổi thay_đổi . đó thay_đổi .
# ------------------------------
# Sentence : a huge famine hit north korea in the mid-1990s .
# Original : vào giữa những năm 90 , bắc triều_tiên trải qua một nạn đói trầm_trọng .
# Translator : một một một nạn 1990 , một cực cũng qua . cuộc đói . .
# ------------------------------
# Sentence : you 'd be surprised how kids are affected by this .
# Original : bạn sẽ ngạc_nhiên khi thấy cách mà những đứa trẻ bị ảnh_hưởng .
# Translator : bạn sẽ ngạc_nhiên thế_nào trẻ_em những mà trẻ_em đứa trẻ bị ảnh_hưởng bởi . .
# ------------------------------
# Sentence : but what if patients could do this test at home ?
# Original : nhưng nếu_như nếu bệnh_nhân có_thể làm xét_nghiệm này ở nhà thì sao ?
# Translator : nhưng nếu bệnh_nhân bệnh_nhân có_thể làm bài này tại nhà ? sao ? .
# ------------------------------
# Sentence : in 2009 , i lost someone i loved very much .
# Original : vào năm 2009 , tôi mất đi một người tôi vô_cùng yêu_quý .
# Translator : vào năm 2009 , tôi mất một một người mà rất yêu . . .
# ------------------------------
# Sentence : here 's me on the same day as this shoot .
# Original : đây là tôi trong cùng một ngày khi chụp bức ảnh trên .
# Translator : đây là tôi cùng cùng một ngày như bắn hình ảnh này . . .
# ------------------------------
# Sentence : this is a blueprint for countries like china and iran .
# Original : đây là một bản_vẽ thiết_kế cho những quốc_gia như trung_quốc hay iran .
# Translator : đây là một bản cho cho các quốc_gia như trung_quốc và iran . . .
# ------------------------------
# Sentence : and i also ask myself , does it really work ?
# Original : tôi cũng đã từng tự hỏi , thực_tế nó có hoạt_động không ?
# Translator : và cũng hỏi hỏi hỏi hỏi mình nó là hoạt_động hiệu_quả ? ?
# ------------------------------
# Sentence : and some even said , this would be 2.0 .
# Original : và một_vài người thậm_chí đã nói , nó giống như 2.0 .
# Translator : và thậm_chí người nói nói nói , đây sẽ như là 2.0 . . .
# ------------------------------
# Sentence : it was cozy in winter but extremely hot in summer .
# Original : khá là ấm_áp trong mùa đông nhưng mùa hè thì cực_kì nóng .
# Translator : nó là tối trong mùa đông nhưng rất hè nóng nóng nóng . .
# ------------------------------
# Sentence : ' the taliban are gone ! ' my father shouted .
# Original : ông ấy la lên : ' bọn taliban đã đi rồi ! '
# Translator : ' là là là ! ' bố tôi của kêu . . ' . .
# ------------------------------
# Sentence : i met on a cold , rainy january night .
# Original : tôi đã gặp trong một đêm tháng_một , mưa và lạnh .
# Translator : tôi gặp gặp những ở một cơn lạnh mưa đêm . đêm . . .
# ------------------------------
# Sentence : why would anyone stay with a man who beats her ?
# Original : tại_sao người phụ_nữ lại nên ở lại với người đã đánh họ ?
# Translator : tại_sao ai lại lại có có đâu với một đàn_ông nhịp nhịp nhịp ? ?
# ------------------------------
# Sentence : otherwise they don ' t come and talk to you .
# Original : không thì họ sẽ chẳng tìm đến mà nói_chuyện với bạn .
# Translator : nếu phải họ không không đến đến và nói với bạn . . . .
# ------------------------------
# Sentence : and that 's a small torch from a broken flashlight .
# Original : và đó là một bóng đèn nhỏ từ cây đèn_pin vỡ .
# Translator : và đó là một ngọn nhỏ nhỏ từ một nổ . . . . .
# ------------------------------
# Sentence : first physically attacked me five days before our wedding .
# Original : đã tấn_công vào tôi năm ngày trước đám_cưới của chúng_tôi .
# Translator : sự đầu_tiên tấn_công tôi tôi 5 ngày trước đám_cưới của chúng_ta . . . .
# ------------------------------
# Sentence : now i 'd like to introduce you to my brothers .
# Original : bây_giờ tôi muốn giới_thiệu các bạn với những người em_trai của tôi
# Translator : bây_giờ tôi muốn giới_thiệu với bạn với anh_em anh_em anh_em của tôi . . . .
# ------------------------------
# Sentence : and they let me go . it was a miracle .
# Original : và họ thả tôi ra . đó quả là một_phép màu .
# Translator : và họ sẽ tôi . . đó là là một màu . . . .
# ------------------------------
# Sentence : gardening is my graffiti . i grow my art .
# Original : làm_vườn là nghệ_thuật của tôi . tôi trồng ra tác_phẩm của mình .
# Translator : làm_vườn là bức của tôi . tôi đã nghệ_thuật nghệ_thuật nghệ_thuật mình . . .
# ------------------------------
# Sentence : image is powerful , but also image is superficial .
# Original : hình_ảnh có sức_mạnh rất lớn , nhưng nó cũng rất là giả_tạo .
# Translator : hình_ảnh là sức_mạnh , nhiều , nhưng cũng cũng là phổ_biến một . . .
# ------------------------------
# Sentence : well , hopefully not as awkward as that picture .
# Original : thật_ra , hy_vọng là nó không đến_nỗi kì_cục như tấm hình này .
# Translator : vâng , hy_vọng không không không phải bức . bức hình này . . .
# ------------------------------
# Sentence : my grandfather was an extraordinary man for his time .
# Original : ông ngoại của tôi là một người thật đáng khâm_phục vào thời ấy
# Translator : ông tôi tôi tôi là một người phi_thường phi_thường kinh_ngạc cho thời_gian của . . .
# ------------------------------
# Sentence : and this is how i decided to maintain it .
# Original : và đây là cách mà tôi trông giữ mảnh đất đó .
# Translator : và đây là cách tôi tôi quyết_định phải nó đất . . .
# ------------------------------
# Sentence : i see wheelchairs bought and sold like used cars .
# Original : tôi nhìn thấy xe_lăn được mua_bán giống như xe cũ vậy .
# Translator : tôi thấy thấy những mua mua và như xe . . . . . .
# ------------------------------
# Sentence : and on the c.d. , this was on .
# Original : và trên chiếc đĩa cd , cái tôi cần đã được ghi trên đó .
# Translator : và trên chiếc bút d. , đây này đang ở ở . lại . .
# ------------------------------
# Sentence : if kids grow kale , kids eat kale .
# Original : nếu bọn trẻ trồng cải xoăn , chúng sẽ ăn cải xoăn .
# Translator : nếu trẻ_em trẻ nuôi những xanh , trẻ_em ăn ăn những xanh .
# ------------------------------
# Sentence : all this is possible with your mobile phone .
# Original : tất_cả những điều đó hoàn_toàn có_thể chỉ với chiếc điện_thoại_di_động của bạn .
# Translator : tất_cả đều gì này có_thể có_thể với với điện_thoại điện_thoại của bạn . . .
# ------------------------------
# Sentence : i see dialysis centers popping up like starbucks .
# Original : tôi thấy các trung_tâm lọc máu mọc lên nhiều như starbucks .
# Translator : tôi thấy các trung_tâm lọc máu xuất_hiện lên như như starbucks . .
# ------------------------------
# Sentence : eventually , our initiative was adopted and successful .
# Original : cuối_cùng thì sáng_kiến của chúng_tôi cũng đã được tiếp_nhận và thành_công .
# Translator : cuối_cùng , , của chúng_tôi được được được chấp_nhận và thành_công . . .
# ------------------------------
# Sentence : instead , everything we touched we killed .
# Original : nhưng thay_vì_thế , chúng_tôi giết chết mọi thứ mà chúng_tôi đụng vào .
# Translator : thay thay , tất_cả đã chết . thứ . thôi đã vào . . .
# ------------------------------
# Sentence : get gangsta with your shovel , okay ?
# Original : làm cùng với cái xẻng của bạn , được chứ ?
# Translator : có cho với với cái nút của bạn , được không ? ?
# ------------------------------
# Sentence : i even went through an identity crisis .
# Original : tôi đã trải qua một cuộc khủng_hoảng về nguồn_gốc của mình .
# Translator : tôi thậm_chí đến qua một cuộc khủng_hoảng bản_sắc bản_sắc . mình . . . .
# ------------------------------
# Sentence : these north koreans were not so lucky .
# Original : nhưng những người bắc triều_tiên này thì không được may_mắn như_vậy .
# Translator : những những người dân triều_tiên không không không may_mắn may_mắn . . .
# ------------------------------
# Sentence : now , we were lucky with our hand - cleaning .
# Original : chúng_tôi đã gặp may với việc lau ảnh bằng tay .
# Translator : bây_giờ đã may_mắn may_mắn với bàn_tay rửa sạch . tay . . . . .
# ------------------------------
# Sentence : however , there is a secret to work with entrepreneurs .
# Original : tuy_nhiên , có một bí_mật để làm_việc với các doanh_nhân .
# Translator : tuy_nhiên , có một bí_mật để làm_việc với các nhà . . . . .
# ------------------------------
# Sentence : growing your own food is like printing your own money .
# Original : trồng thực_phẩm cho mình cũng giống tự in tiền vậy .
# Translator : trồng thức_ăn của bạn là như như in của của . . . . .
# ------------------------------
# Sentence : growing one plant will give you 1,000 , 10,000 seeds .
# Original : trồng một cây sẽ cho bạn 1.000 , 10.000 hạt_giống .
# Translator : một một cây sẽ cho bạn 1000 hạt_giống triệu hạt . . . .
# ------------------------------
# Sentence : and when presenting your work , drop the bullet points .
# Original : và khi trình_bày , đừng sử_dụng những gạch đầu dòng .
# Translator : và khi đưa công_việc bạn có viên điểm đạn . . . . . .
# ------------------------------
# Sentence : sometimes , i saw dead bodies floating down the river .
# Original : và tôi đã nhìn thấy xác họ nổi trên sông .
# Translator : đôi_khi đôi_khi thấy thấy thấy cơ_thể chết chết lên sông . . . . .
# ------------------------------
# Sentence : it could take an hour . it could take weeks .
# Original : có_thể mất một giờ . có_thể mất cả tuần .
# Translator : nó lấy một giờ . nó mất đi tuần . . . . . .
# ------------------------------
# Sentence : what are you going to get out of those samples ?
# Original : bạn sẽ kết_luận được gì từ những mẫu này ?
# Translator : bạn sẽ lấy gì gì ? những mẫu này ?
# ------------------------------
# Sentence : it was the only way we both could be educated .
# Original : đó là cách duy_nhất để chúng_tôi có_thể đi học .
# Translator : đó là cách duy_nhất chúng_ta chúng_ta có_thể được học . . . . . .
# ------------------------------
# Sentence : i want to challenge that . do you know why ?
# Original : tôi muốn phản_kháng lại vì bạn biết sao không ?
# Translator : tôi muốn thách_thức thách_thức thách_thức điều biết tại_sao ? ?
# ------------------------------
# Sentence : ' i ' m helping the north korean people . '
# Original : ' ' tôi đang giúp người bắc triều_tiên . '
# Translator : ' tôi tôi đang giúp người hàn_quốc triều_tiên ' ' ' . .
# ------------------------------
# Sentence : i couldn ' t give them money , nothing .
# Original : tôi chẳng cho họ tiền được , không gì cả .
# Translator : tôi không_thể có họ tiền , không không . cả . . . . .
# ------------------------------
# Sentence : which presentation have you applauded the most this morning ?
# Original : bài thuyết_trình nào bạn vỗ_tay nhiều nhất trong sáng nay ?
# Translator : bạn thuyết_trình có có có nhất nhất trong buổi nay ?
# ------------------------------
# Sentence : can they really store all this information about us ?
# Original : liệu họ có_thể lưu lại toàn_bộ thông_tin của chúng_ta không ?
# Translator : họ họ có_thể thực_sự lại tất_cả thông_tin về chúng_ta ? ?
# ------------------------------
# Sentence : vultures are amongst the most threatened group of birds .
# Original : kền_kền là một trong những nhóm chim bị đe_doạ nghiêm_trọng nhất
# Translator : chim đang giữa nhóm những nhóm bị . đe_doạ nhất nhất . . . . .
# ------------------------------
# Sentence : the question , ' why does she stay ? '
# Original : câu hỏi , ' tai_sao cô ấy ở lại ? '
# Translator : câu hỏi , ' tại_sao cô ấy lại lại ? ' '
# ------------------------------
# Sentence : back to my question : why did i stay ?
# Original : trở_lại câu hỏi của tôi : tại_sao tôi ở lại ?
# Translator : quay với hỏi của tôi : tại_sao tôi lại lại ở .
# ------------------------------
# Sentence : he shares it unconditionally and he shares it regardless .
# Original : em chia_sẻ nó một_cách vô điều_kiện dù sao chăng_nữa .
# Translator : ông chia_sẻ nó với không điều_kiện và nó và . . . . .
# ------------------------------
# Sentence : we had an amazing local woman who guided us .
# Original : có một người phụ_nữ địa_phương tuyệt_vời đã hướng_dẫn chúng_tôi .
# Translator : chúng_tôi một người phụ_nữ địa_phương tuyệt_vời . có chúng_tôi . . . . . .
# ------------------------------
# Sentence : what can you do ? can you make it ?
# Original : bạn có_thể làm gì ? bạn làm được không ?
# Translator : bạn có_thể làm gì ? bạn có_thể gì gì ? ?
# ------------------------------
# Sentence : because this time it wasn ' t coming up .
# Original : vì lần này thì chuyện này không tới đâu .
# Translator : bởi_vì thời_gian này không nó này không xuất_hiện . . .
# ------------------------------
# Sentence : thing is , it 's owned by the city .
# Original : vấn_đề là , mảnh đất đó thuộc về thành_phố .
# Translator : đó là , nó sở_hữu của là thành_phố thành_phố . . . .
# ------------------------------
# Sentence : hopefully less awkward than that one in the middle .
# Original : hi_vọng là nó ít kì_cục hơn tấm hình ở giữa
# Translator : hy_vọng ít không không khó_khăn hơn một hình này giữa . . . . . .
# ------------------------------
# Sentence : may we all be granted a grace of mercy .
# Original : cầu cho mỗi chúng_ta được ân_sủng của lòng khoan_dung .
# Translator : chúng_ta có_thể tất_cả chúng_ta đều biết của một trung_thành . . . . . .
# ------------------------------
# Sentence : we need to work with governments in regional levels .
# Original : chúng_ta cần hợp_tác với chính_phủ trên mức_độ vùng miền .
# Translator : chúng_ta cần làm_việc với chính_phủ ở khu_vực địa_phương địa_phương . . . . . .
# ------------------------------
# Sentence : so actually , i was in very good company .
# Original : vì_vậy , tôi thật_sự đã ở trong công_ty rất tốt
# Translator : thực_ra , tôi đã rất rất công_ty công_ty rất tốt . . . . . .
# ------------------------------
# Sentence : also , asphalt can create a lot of noise .
# Original : ngoài_ra , nhựa_đường cũng gây ra nhiều tiếng ồn .
# Translator : cũng , có_thể có_thể có_thể ra rất tiếng ồn . . . .
# ------------------------------
# Sentence : that equates to about $ 50,000 in today 's money .
# Original : tương_đương với 50.000 đô - la mỹ ngày_nay .
# Translator : điều với khoảng đô_la - la vào ngày_nay là . . . . .
# ------------------------------
# Sentence : so i didn ' t give up . i continued .
# Original : nhưng tôi không từ_bỏ . tôi tiếp_tục suy_nghĩ .
# Translator : tôi tôi không từ_bỏ . tôi tiếp_tục . . . . . . .
# ------------------------------
# Sentence : ninety - nine . well , that 's an improvement .
# Original : chín_mươi chín . vâng , một tiến_bộ .
# Translator : 90 . . vâng , đó sự . . . .
# ------------------------------
# Sentence : jargon is a barrier to our understanding of your ideas .
# Original : thuật_ngữ ngăn_cản chúng_tôi hiểu được ý_tưởng của anh .
# Translator : thuật_ngữ là sự hiểu ý_tưởng ý_tưởng của bạn . . . . .
# ------------------------------
# Sentence : do not help to prevent the spread of diseases .
# Original : quân_cảnh không giúp ngăn_chặn sự lây_lan của bệnh_tật .
# Translator : việc không giúp ngăn_chặn sự lan_truyền của các . . . .
# ------------------------------
# Sentence : please don ' t tell me i ' m normal .
# Original : xin đừng nói với tôi rằng tôi bình_thường .
# Translator : đừng đừng nói với tôi rằng tôi là . . . . . .
# ------------------------------
# Sentence : this was one of the lowest points in my life .
# Original : đó là thời_điểm tuyệt_vọng nhất trong cuộc_đời tôi .
# Translator : đây là một duy_nhất nhất của cuộc_sống tôi . . . . . . .
# ------------------------------
# Sentence : he was petrified he would be knocked in the water .
# Original : cậu bé khiếp_đảm vì sợ rơi xuống_nước .
# Translator : ông ấy ấy đến anh anh vào . . . . . . .
# ------------------------------
# Sentence : that 's enough space to plant million tomato plants .
# Original : đủ để trồng triệu cây cà_chua .
# Translator : đó không_gian làm cây triệu cây cà_chua triệu . . . . . .
# ------------------------------
# Sentence : so there 's two types of vultures in this planet .
# Original : có hai loại kền_kền trên hành_tinh này .
# Translator : vậy hai loại chim ở hành_tinh này . . . . . . . .
# ------------------------------
# Sentence : ' we have no freedom , ' they said .
# Original : họ nói , ' chúng_tôi không có tự_do ,
# Translator : ' không ' ' chúng_ta không có tự_do ' ' . . . .
# ------------------------------
# Sentence : there were no windows large enough to climb through .
# Original : chẳng có cửa_sổ đủ lớn mà chui lọt .
# Translator : không có cửa_sổ nào lớn để để qua qua . . . . . .
# ------------------------------
# Sentence : i couldn ' t offer them any direct help .
# Original : tôi đã không_thể trực_tiếp giúp gì cho họ .
# Translator : tôi không_thể không_thể cho cho họ cả họ bất_cứ . . . . . .
# ------------------------------
# Sentence : i shut up , and listen to them . '
# Original : tôi im miệng , và lắng_nghe họ . '
# Translator : tôi đã , , và lắng_nghe họ . ' '
# ------------------------------
# Sentence : and of course , everything in africa grew beautifully .
# Original : và tất_nhiên , mọi thứ tại châu_phi_đều phát_triển tốt
# Translator : và tất_nhiên , mọi thứ ở châu có đẹp . . . . . . .
# ------------------------------
# Sentence : food is the problem and food is the solution .
# Original : thực_phẩm là vấn_đề và thực_phẩm cũng là giải_pháp .
# Translator : thực_phẩm là vấn_đề và thực_phẩm là là giải_pháp . . . .
# ------------------------------
# Sentence : so i figured that the problem is the solution .
# Original : tôi nhận ra rằng vấn_đề chính là giải_pháp .
# Translator : vì_vậy đã ra rằng vấn_đề là là giải_pháp . .
# ------------------------------
# Sentence : so do you still not want to continue ? '
# Original : vậy thì con còn muốn tiếp_tục nữa không ?
# Translator : vậy bạn bạn vẫn không tiếp_tục ? ? ? '
# ------------------------------
# Sentence : there are 10,000 species of birds in the world .
# Original : hiện có khoảng 10,000 loài chim trên thế_giới .
# Translator : có có 10,000 10,000 loài chim ở thế_giới . .
# ------------------------------
# Sentence : i didn ' t know he was abusing me .
# Original : tôi không biết anh ta đang bạo_hành tôi .
# Translator : tôi không biết ông ta bị bị tôi . . . . . . .
# ------------------------------
# Sentence : this wasn ' t a brothel , per se .
# Original : nơi đây thực_chất không phải nhà thổ .
# Translator : đây này không không phải là tài_trợ , . . . . . . .
# ------------------------------
# Sentence : one of them got caught up in the water .
# Original : một đứa bị kẹt trong dòng nước .
# Translator : một trong trẻ bắt trong nước nước . . . . . .
# ------------------------------
# Sentence : first question to answer for us : so what ?
# Original : câu hỏi đầu_tiên là : gì cơ ?
# Translator : câu hỏi đầu_tiên cho câu vậy ? chứ là
# ------------------------------
# Sentence : this directive   is   called data retention directive .
# Original : nó được gọi là chỉ_thị dữ_liệu .
# Translator : đây là gọi là dữ_liệu gọi . . . . . . . . .
# ------------------------------
# Sentence : thus began my journey into modern day slavery .
# Original : và từ đó bắt_đầu cuộc hành_trình tiến vào thế_giới nô_lệ hiện_đại
# Translator : vì_vậy bắt_đầu đó bắt_đầu hành_trình hành_trình của vào ngày hiện_đại hiện_đại . . . . .
# ------------------------------
# Sentence : nobody started a company alone . no one .
# Original : không ai khởi_đầu một công_ty một_mình . không ai cả .
# Translator : không ai bắt_đầu một công_ty nào . không . . . . . . .
# ------------------------------
# Sentence : and when we do this , who knows ?
# Original : và khi chúng_ta làm_việc đó , ai mà biết được ?
# Translator : và khi chúng_ta làm này , ai biết biết ? ? .
# ------------------------------
# Sentence : this is on the street for a reason .
# Original : mảnh vườn này nằm trên đường là có_lí_do của nó .
# Translator : đây phố phố là trên đường cho lý_do . nó .
# ------------------------------
# Sentence : it 's about knowing you 're not alone .
# Original : đó là về biết rằng bạn không chỉ có một_mình .
# Translator : nó là về việc bạn bạn không chỉ một_mình một_mình . .
# ------------------------------
# Sentence : you have to fight for it every day .
# Original : và bạn phải đấu_tranh không ngừng_nghỉ cho nó mỗi ngày .
# Translator : bạn bạn phải đấu_tranh cho cho cho mỗi mỗi ngày . .
# ------------------------------
# Sentence : they have been associated in ancient egyptian culture .
# Original : chúng đã được kết liên với nền văn_hoá ai cập cổ_đại
# Translator : họ đã được kết_nối với qua văn_hoá văn_hoá cổ_đại cập . . . . . .
# ------------------------------
# Sentence : first , you have to offer them .
# Original : trước_tiên , bạn phải mang đến cho họ sự bảo_mật
# Translator : đầu_tiên , bạn phải cho cho cho họ những pha_trộn . . . . . .
# ------------------------------
# Sentence : way of maintaining things is not sustainable .
# Original : đường_lối để lưu_trữ các thứ là không bền_vững .
# Translator : cách của của duy_trì mọi thứ không không bền_vững . . . .
# ------------------------------
# Sentence : so what you do -- you shut up .
# Original : vậy bạn làm gì - - bạn im miệng .
# Translator : vậy nên làm gì - - bạn đóng_cửa . . . .
# ------------------------------
# Sentence : and the indicator box makes the lights flash .
# Original : và chiếc hộp đồng_hồ đo làm cho tắt .
# Translator : và những hộp cho tạo làm cho ánh_sáng . . . . . . .
# ------------------------------
# Sentence : if they grow tomatoes , they eat tomatoes .
# Original : nếu chúng trồng cà_chua , chúng sẽ ăn cà_chua .
# Translator : nếu chúng trồng cà_chua , họ ăn ăn cà_chua . .
# ------------------------------
# Sentence : and i figured , this has to stop .
# Original : và tôi nhận ra rằng điều đó phải chấm_dứt .
# Translator : và tôi đã ra rằng , này đã dừng . .
# ------------------------------
# Sentence : liquor stores , fast food , vacant lots .
# Original : cửa_hàng rượu , đồ ăn nhanh , đất hoang .
# Translator : các đồ , thức_ăn ăn nhanh , rất . . . . . . .
# ------------------------------
# Sentence : thanks so much . max little , everybody .
# Original : cảm_ơn rất nhiều . hoan_nghênh nào mọi người .
# ...
# ------------------------------
# Sentence : anyone healthy or with parkinson 's can call in , cheaply , and leave recordings , a few cents each , and i ' m really happy to announce that we ' ve already hit six percent of our target just in eight hours .
# Original : bất_cứ ai khoẻ_mạnh hoặc mắc bệnh parkinson có_thể gọi tới với giá rẻ , và để lại âm ghi , vài xu mỗi lần , và tôi thực_sự vui_mừng thông_báo rằng chúng_tôi đã đạt sáu phần_trăm mục_tiêu chỉ trong tám giờ .
# Translator : bất_cứ ai hay hay với bệnh parkinson , gọi là , giá rẻ , và để lại một , lại một_vài cent , cent , và tôi thực_sự rất được rằng chúng_ta đã có được % của của trong vòng giờ . . của . . . . . . . . . . . . . . . .
# ------------------------------
# Sentence : because autistic or not , the differences that we have -- we ' ve got a gift ! everyone 's got a gift inside of us , and in all honesty , the pursuit of normality is the ultimate sacrifice of potential .
# Original : vì có mắc chứng tự kỷ hay không , sự khác_biệt giữa chúng_ta - - chúng_ta có một món quà ! ai cũng mang trong mình một món quà , và thật lòng mà nói , theo_đuổi cái bình_thường chính là hi_sinh tiềm_năng lớn nhất .
# Translator : bởi_vì không người chứng tự kỷ , không , những khác_biệt mà chúng_ta - - chúng_ta có một món quà ! mọi cũng có lại chúng_ta , món quà , và tất_cả là can_đảm sự , sự sự thói_quen là là sự của . nhất . . . . . . . . . . . . . . .
# ------------------------------
# Sentence : photography has been my passion ever since i was old enough to pick up a camera , but today i want to share with you the 15 most photos of mine , and i didn ' t take any of them .
# Original : nhiếp_ảnh là niềm đam_mê của tôi kể từ khi tôi đủ lớn để cầm một chiếc máy_ảnh , nhưng hôm_nay tôi muốn chia_sẻ với các bạn 15 bức ảnh mà tôi trân_trọng nhất , và tôi không tự chụp cái nào trong số đó .
# Translator : nhiếp_ảnh đã một đam_mê của tôi từ từ khi tôi đủ già để chọn một chiếc máy , nhưng hôm_nay tôi muốn chia_sẻ với các bạn 15 tuổi ảnh hầu_hết hầu_hết đã , , và tôi không bao_giờ lấy bất_cứ gì . số họ . . . . . . . . . . . . . . . .
# ------------------------------
# Sentence : so what i want to propose to you as an unconventional way in which we can try to achieve this , because , you see , in one sense , at least , we are all like my friend jan .
# Original : vì_vậy , cái tôi muốn đề_xuất cho bạn là một_cách qua đó ta có_thể đạt được điều này , vì như bạn thấy , ít_nhất theo một hướng nào đó , chúng_ta đều là những bậc thầy như bạn tôi .
# Translator : vì_vậy , tôi tôi muốn đề_xuất với các như một khác_thường mà những , có_thể cố_gắng được điều này , bởi_vì bạn bạn thấy , trong là cách , , đó , chúng_tôi đều giống tất_cả người như của bạn của . . . . . . . . . . . . . . . . . . .
# ------------------------------
# Sentence : this is one of the cows which was killed at night , and i just woke up in the morning and i found it dead , and i felt so bad , because it was the only bull we had .
# Original : đây là một trong số những con bò đã bị giết vào buổi tối , và khi thức dậy vào buổi sáng tôi tìm thấy nó đã chết , và tôi đã cảm_thấy rất buồn , bởi_vì đó là con bò đực duy_nhất mà chúng_tôi có .
# Translator : đây là một trong những những con bò đã bị giết vào đêm tối , và tôi tôi dậy vào buổi sáng và thấy thấy nó chết chết , và tôi cảm_thấy cảm_thấy quá tệ vì vì nó chỉ con bò duy_nhất duy_nhất chúng_ta chúng_ta đã . . . . . . . . . . . . . .
# ------------------------------
# Sentence : recently , on one trip , we were walking , and she stops dead in her tracks , and she points to a red of the doll store that she loved when she was little on our earlier trips .
# Original : gần đây , trong một chuyến đi , chúng_tôi đang đi bộ thì con_gái tôi đột_ngột dừng lại giữa đường , và nó chỉ đến mái_hiên màu đỏ của cửa_hàng búp_bê mà nó rất thích khi còn nhỏ trong những chuyến đi trước đây của chúng_tôi .
# Translator : gần đây , một một chuyến đi , chúng_tôi đi đi , , cô đã đã , lại trong cô và và bà là là một cho đỏ của chiếc dvd đỏ cô yêu thích khi cô nhỏ lên chuyến chuyến đi đầu . . chúng_tôi . . . . . . . . . . . . . .
# ------------------------------
# Sentence : in tibetan culture , they are performing very important sky burials . in places like tibet , there are no places to bury the dead , or wood to them , so these vultures provide a natural disposal system .
# Original : trong nền văn_hoá tibet , họ thực_hiện rất quan_trọng . tại những nơi như ở tibet , chẳng có chỗ để chôn người chết , hoặc chẳng có củi để thiêu họ , vậy nên những con kền_kền cung_cấp một hệ_thống sử lí chất_thải tự_nhiên .
# Translator : trong văn_hoá văn_hoá ở , họ đang rất rất quan_trọng . ở những nơi như tây_tạng tây_tạng , không có những nào chôn vùi chết , hoặc là có gỗ cho chúng cháy , nên nên những con vật này một hệ_thống tự_nhiên tự_nhiên tự_nhiên tự_nhiên . . . . . . . . . . . . . .
# ------------------------------
# Sentence : so that 's what we did here . you see where we were making the test road , and then of course this road will last several years without any damage . that 's what we know from practice .
# Original : vậy là đó là điều chúng_tôi đã thực_hiện tại đây . bạn xem con đường thử_nghiệm chúng_tôi đã làm , và rồi đương_nhiên con đường này sẽ tồn_tại được trong nhiều năm mà không bị hư_hại nào . đó là những gì chúng_tôi học từ thực_nghiệm .
# Translator : vậy là những , những chúng_tôi làm làm ở đây . bạn thấy chúng_ta đường đã , đang kiểm_tra gì và tất_nhiên tất_nhiên con đường này sẽ không trong vài vài năm qua không có tổn_thương gì . chúng_ta là những gì chúng_ta biết được . . . . . . . . . . . . . . .
# ------------------------------
# Sentence : and across the world , every 20 minutes , one new person is diagnosed with autism , and although it 's one of the fastest - growing developmental disorders in the world , there is no known cause or cure .
# Original : và trên toàn thế_giới , cứ 20 phút lại có thêm một người được chẩn_đoán mắc chứng tự kỷ , và mặc_dù nó là một trong những chứng rối_loạn phát_triển với tốc_độ nhanh nhất trên thế_giới , ta không rõ nguyên_nhân hoặc cách chữa_trị .
# Translator : và trên thế_giới thế_giới , mỗi 20 phút , là người một người mới chẩn_đoán mắc chứng tự kỷ , mặc_dù mặc_dù đó là một trong những rối_loạn rối_loạn phát_triển nhanh thế_giới phát_triển nhất thế_giới thế_giới , không không hề là hay chữa chữa . . . . . . . . . . . . . . . .
# ------------------------------
# Sentence : so i asked my phone company , , which was at that time the largest phone company in germany , and i asked them , please , send me all the information you have stored about me .
# Original : do đó tôi đã yêu_cầu nhà mạng mình sử_dụng , , nhà cung_cấp dịch_vụ viễn_thông lớn nhất của đức tại thời_điểm đó , và tôi đã yêu_cầu họ , làm_ơn , hãy gửi cho tôi toàn_bộ thông_tin của tôi mà họ đã lưu_trữ .
# Translator : vì_vậy đó tôi hỏi hỏi công_ty điện_thoại của , , tên , đó , cho này lớn nhất ở tôi , đức , , tôi tôi hỏi hỏi họ , xin gửi gửi gửi tất_cả tôi thông_tin thông_tin bạn các đã bạn đã lưu_trữ . . . . . . . . . . . . . . . .
# ------------------------------
# Sentence : what i ' m talking about is putting people to work , and getting kids off the street , and letting them know the joy , the pride and the honor in growing your own food , opening farmer 's markets .
# Original : tôi đang nói về việc giao công_việc cho mọi người , và kéo bọn trẻ ra khỏi phố , và cho chúng biết niềm vui , niềm tự_hào và niềm vinh_dự khi tự trồng thực_phẩm cho mình , mở chợ cho nông_dân .
# Translator : tôi đang nói về việc đặt cho của mọi người , và kiếm con trẻ ra khỏi phố , để cho họ biết niềm vui , niềm tự_hào và niềm tự_hào ở đang phát_triển trong của chính , những thị_trường của thị_trường . . . . . . . . . . . . . . . . . .
# ------------------------------
# Sentence : and those things are true , but they 're only one half of the story , because the thing that we never say on camera , that i have never said on camera , is , ' i am insecure . '
# Original : và những điều đó là sự_thật , nhưng đó chỉ là một nửa thôi , vì điều mà chúng_tôi không bao_giờ nói ra trước ống_kính , điều mà tôi không bao_giờ nói trước ống_kính , là : ' tôi bất_an ' .
# Translator : và những thứ đó là sự_thật , nhưng chúng chỉ là một nửa câu_chuyện , vì điều mà chúng_tôi chưa bao_giờ nói , , , , tôi mà tôi chưa bao_giờ nói về , , ' , ' tôi không . . . . . . . . . . . . . . . . . . .
# ------------------------------
# Sentence : when i met him , he had been working in the mines for 14 years , and the leg injury that you see here is actually from a mining accident , one so severe doctors say his leg should be amputated .
# Original : khi tôi gặp , anh ta đã làm_việc 14 năm ở khu mỏ , và vết_thương ở chân mà bạn thấy đây là từ 1 tai_nạn ở mỏ , một chân bị_thương nặng đến_nỗi bác_sĩ nói phải cưa đi .
# Translator : khi tôi gặp ông ông ta đã làm_việc trong năm , đây nhà này và chấn_thương mà đây bạn bạn thấy ở là từ một tai_nạn , một , một bác_sĩ nặng nặng của con của chân là . . . . . . . . . . . . . . . . . . . . . .
# ------------------------------
# Sentence : i remember this time , there was this mother and a daughter came , it was , like , 10 : 30 at night , and they were in my yard , and i came out and they looked so ashamed .
# Original : tôi nhớ có một lần , có một người mẹ và con_gái tới , lúc đó là khoảng 10 : 30 tối và họ ở trong vườn của tôi . rồi tôi đi ra ngoài và họ rất xấu_hổ .
# Translator : tôi nhớ rằng thời_gian lúc này có một mẹ mẹ và con_gái đã , nó đó , , 10 : 30 đêm , họ đang trong sân của tôi , và tôi đi ra và và họ cảm_thấy xấu_hổ . . . . . . . . . . . . . . . . . . . . .
# ------------------------------
# Sentence : well , for the past few centuries we have defined beauty not just as health and youth and symmetry that we 're biologically programmed to admire , but also as tall , slender figures , and and white skin .
# Original : trong những thập_kỉ vừa_qua , chúng_ta đã định_nghĩa sắc_đẹp không chỉ là khoẻ_mạnh và trẻ_trung và sự cân_đối mà chúng_ta được lập_trình về mặt sinh_học để khao_khát mà còn là chiều cao , những đường_nét và nữ_tính , và da trắng .
# Translator : trong vài thế_kỷ qua chúng_tôi chúng_ta đã định_nghĩa những như chỉ sức_khoẻ sức_khoẻ và những một_cách sự cơ_bản mà chúng_ta được lập_trình để mặt sinh_học , ngưỡng_mộ , còn là những cao , và con_số và và da và và da trắng . . . . . . . . . . . . . . . . . .
# ------------------------------
# Sentence : you could be the president of the united states , or the inventor of the next internet , or a ninja cardio - thoracic surgeon poet , which would be awesome , because you 'd be the first one . '
# Original : bạn có_thể trở_thành tổng_thống nước mỹ , hoặc người phát_minh ra một internet tiếp_theo , hay là một nhà_thơ bác_sĩ phẩu thuật tim_mạch ninja , sẽ rất tuyệt_vời phải không , vì em sẽ là người đầu_tiên làm chuyện đó ' .
# Translator : bạn có_thể là tổng_thống của mỹ , hay nhà phát_minh của internet mạng hay hay hay một một nhà của phẫu_thuật thuật , , , sẽ rất tuyệt , vì , vì bạn là là một đầu_tiên . . . . ' . . . . . . . . . . . . . . . . .
# ------------------------------
# Sentence : and i was wondering , how would you feel if you had no access to healthy food , if every time you walk out your door you see the ill effects that the present food system has on your neighborhood ?
# Original : và tôi tự hỏi , bạn cảm_thấy thế_nào khi không có thực_phẩm có lợi cho sức_khoẻ , khi mỗi lần ra khỏi cửa bạn phải nhìn thấy những tác_động xấu mà hệ_thống thực_phẩm hiện_nay gây ra cho nơi mình sinh_sống ?
# Translator : và tôi đã hỏi , làm sẽ nếu nếu bạn có được khoẻ_mạnh quyền cho mỗi , nếu mỗi lần bạn khỏi cửa bạn nhìn nhìn thấy những ảnh_hưởng gây mà hệ_thống thực_phẩm có có ra trên bạn trên ? ? ? của của của của của của của của của của của của của của của của của của
# ------------------------------
# Sentence : when charles darwin went across the atlantic in on the beagle , he saw the turkey vulture , and he said , ' these are disgusting birds with bald scarlet heads that are formed to revel in . '
# Original : khi charles darwin vượt qua thái_bình_dương năm từ tàu beagle , ông thấy những con kền_kền thổ_nhĩ_kỳ , ông nói , ' những con chim này thật kinh_tởm với cái đầu trọc được tạo ra để hoan_hỉ trong hôi_thối
# Translator : khi charles darwin đi qua phía trong đầu trên những , , ông thấy con con bé , , ông nói , ' đây con chim này thật kinh_khủng với những đầu bị đầu mà hình_thành ra để làm . ' . . . . . . . . . . . . . . . . . . . .
# ------------------------------
# Sentence : back in the , i wanted to cry , but the next to me quickly grabbed me and he said , ' lisa , don ' t do that . just don ' t do that here . '
# Original : quay lại lò gạch , tôi chỉ muốn khóc , nhưng người bản theo chủ_nghĩa bãi nô bên cạnh nhanh_chóng nắm lấy tôi và nói , ' lisa , đừng làm thế . đừng làm thế ở đây . '
# Translator : quay trở_lại với , , tôi muốn muốn khóc , nhưng những đã ' tôi tôi tiếp_theo này cạnh tôi tôi tôi tôi và nói , ' rw , đừng làm điều . ' làm điều này đây . ' . này này này này này này này này này này này này này này này này này . .
# ------------------------------
# Sentence : right now , maybe you 're thinking , ' wow , this is fascinating , ' or , ' wow , how stupid was she , ' but this whole time , i ' ve actually been talking about you .
# Original : ngay lúc này , có_thể bạn đang nghĩ , ' ồ , điều này thật tuyệt_vời ' hay , ' ồ , cô ấy mới ngốc làm_sao ' nhưng tất_cả thời_gian này , tôi đã thật_sự nói về bạn .
# Translator : ngay bây_giờ này , có_lẽ bạn nghĩ nghĩ , ' wow , thật này thật thú_vị , hay ' ' wow , thật ấy thật thật , , nhưng lần lần này , tôi đã thực_sự đã về bạn . . . . . . . . . . . . . . . . . . . . .
# ------------------------------
# Sentence : yet beyond the tantrums and the frustration and the never - ending hyperactivity was something really unique : a pure and innocent nature , a boy who saw the world without prejudice , a human who had never lied .
# Original : nhưng ngoài cơn phẫn_nộ và bực_dọc và việc hiếu_động thái_quá không ngơi_nghỉ là một điều gì đó thực_sự độc_đáo : một bản_năng thuần_khiết và ngây_thơ , một cậu bé nhìn cuộc_đời không chút định_kiến , một con_người không bao_giờ nói_dối .
# Translator : tuy_nhiên ngoài nỗi bão và sự và sự này quá đến bao_giờ của một thứ đặc_biệt đó : đặc_biệt và và bản_chất và và bản_chất , một cậu bé nhìn thấy mà có nào , mà người chưa bao_giờ bị . . . . . . . . . . . . . . . . . . . .
# ------------------------------
# Sentence : in school , we spent a lot of time studying the history of kim il - sung , but we never learned much about the outside world , except that america , south korea , japan are the enemies .
# Original : ở trường , chúng_tôi dành rất nhiều thời_gian để học về cuộc_đời của chủ_tịch kim ii - sung , nhưng lại không học nhiều về thế_giới bên ngoài , ngoại_trừ việc hoa_kỳ , hàn_quốc và nhật_bản là kẻ_thù của chúng_tôi .
# Translator : trong trường , chúng_tôi đã rất nhiều thời_gian nghiên_cứu nghiên_cứu lịch_sử lịch_sử của người của tiêm , - , nhưng chúng_tôi chưa bao_giờ được về thế_giới bên ngoài , trừ nước mỹ , hàn_quốc , nhật_bản là kẻ_thù . kẻ_thù . . . . . . . . . . . . . . . . . . . .
# ------------------------------
# Sentence : approaching my daughter 's third birthday , my wife said , ' hey , why don ' t you take back to new york and make it a father - daughter trip , and continue the ritual ? '
# Original : khi sắp tới sinh_nhật lần thứ 3 của con_gái tôi , vợ tôi nói , ' sao anh không đưa đến new_york làm một chuyến du_lịch chỉ có cha và con_gái , rồi tiếp_tục ' nghi_thức ' cũ ?
# Translator : tôi con_gái con_gái con_gái thứ thứ ba , tôi tôi nói ' tôi nói , ' tại_sao không không lấy bạn trở_lại new_york và cho con đi , ra con_gái , con_gái , và tiếp_tục nghi_lễ này ? ' . ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
# ------------------------------
# 2.6753539443016052 0.15891175397177124
